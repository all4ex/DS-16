# %% [markdown]
# # Один из возможных алгоритмов скрейпинга
#
# * указать в коде адрес интересующего сайта: откуда вы хотите скачать данные?
# для этого используется библиотека requests
#
# * сохранить веб-страницу (html-код страницы)
#
# * выбрать данные, которые нужно собрать (используется BeautifulSoup)
#
# * записать данные в csv-файл.
#
# Если нужно соскрейпить несколько страниц - повторяем процесс для каждой из них.

# %% [markdown]
# **Наша задача:** выгрузить недавние новости в датафрейм `pandas`, чтобы потом сохранить все в csv-файл.
#
# Сначала сгрузим весь html-код страницы и сохраним его в отдельную переменную. Для этого нам понадобится библиотека `requests`. Документация: https://requests.readthedocs.io/en/latest/
#
# Импортируем её:

# %%
import requests

# %% [markdown]
# Сохраним ссылку на главную страницу сайта в переменную `url` для удобства и выгрузим страницу. (Разумеется, это будет работать при подключении к интернету. Если соединение будет отключено, Python выдаст `NewConnectionError`).

# %%
url = 'https://nplus1.ru/' # сохраняем
page = requests.get(url) # загружаем страницу по ссылке

# %% [markdown]
# Если мы просто посмотрим на объект, мы ничего особенного не увидим:

# %%
page  # response 200 - страница загружена
# Out:
# <Response [200]>

# %% [markdown]
# **BeautifulSoup** - python-библиотека для синтаксического разбора файлов HTML/XML. В веб-разработке «суп из тегов» (tag soup) - это слово для синтаксически или структурно некорректного HTML, написанного для веб-страницы.
#
# Документация: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# Импортируем функцию `BeautifulSoup` из библиотеки `bs4` (от *beautifulsoup4*) и заберём со страницы `page` код html в виде текста.
#
# Сохраним в переменную 'soup' весь HTML-код страницы. HTML-код - это "дерево тегов", формирующее контент страницы.

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\kimob\anaconda3\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kimob\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
from bs4 import BeautifulSoup 
# название - отсылка к песне про суп из Алисы в стране чудес https://aliceinwonderland.fandom.com/wiki/Turtle_Soup

# %%
soup = BeautifulSoup(page.text, 'html')

# %% [markdown]
# Если выведем `soup` на экран, мы увидим то же самое, что в режиме разработчика или в режиме происмотра исходного кода (`view-source` через *Ctrl+U* в Google Chrome).

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>N + 1 — главное издание о науке, технике и технологиях</title>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
# <link href="/front-build/css/main.css?id=9b496fbb252428c03791da99722528ab" rel="stylesheet"/>
# <link href="/front-build/css/app.css?id=116ee51fc89adfd59429b373ba12b060" rel="stylesheet"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#f26e40" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://nplus1.ru" rel="canonical"/>
# <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
# <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');</script>
# <!-- End Google Tag Manager -->
# <meta content="N + 1 - это научно-популярное издание, которое познакомит вас с природными явлениями, открытиями и технологиями, расскажет
#  просто о сложном и поможет узнать что-то новое для себя" name="description"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:title"/>
# <meta content="https://nplus1.ru/images-new/share_snippet.png" property="og:image"/>
# <meta content="https://nplus1.ru" property="og:url"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
# <meta content="" property="og:type"/>
# <script type="application/ld+json">
# {
# 	"@context": "http://schema.org",
# 	"@type": "WebSite",
# 	"url": "https://nplus1.ru/",
# 	"name": "N + 1 — главное издание о науке, технике и технологиях",
# 	"description": "N + 1 — главное издание о науке, технике и технологиях",
# 	"image": "https://staticn1.nplus1.ru/image-new/share_snippet.png",
# 	"publisher": {
# 	"@type": "Organization",
# 		"name": "N+1",
# 		"logo": {
# 			"@type":"ImageObject",
# 			"url": "https://staticn1.nplus1.ru/image-new/logo-alt.png"
# 		},
# 		"sameAs": [
# 			"https://www.facebook.com/nplusone",
# 			"https://twitter.com/nplusodin",
# 			"https://vk.com/nplusone",
# 			"https://ok.ru/nplus1",
# 			"https://soundcloud.com/nplus_1",
# 			"https://t.me/nplusone"
# 		]
# 	},
# 	"potentialAction":{
# 		"@type":"SearchAction",
# 		"target":"https://nplus1.ru/search/{search_term_string}",
# 		"query-input":"required name=search_term_string"
# 	}
# }
#
#   </script>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@nplusodin" name="twitter:site"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:title"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
# <meta content="https://nplus1.ru/images-new/share_snippet.png" name="twitter:image"/>
# <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# </head>
# <body class="antialiased">
# <!-- Top.Mail.Ru counter -->
# <script type="text/javascript">
#
# var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#
# </script>
# <noscript><div><img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/></div></noscript>
# <!-- /Top.Mail.Ru counter -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
# <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
# <div class="border-b border-main-gray h-full">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
# <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
# <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
# <svg class="w-full h-full">
# <use xlink:href="#n1_cross_menu"></use>
# </svg>
# </template>
# <template v-else="">
# <svg class="w-full h-full">
# <use xlink:href="#n1_burger"></use>
# </svg>
# </template>
# </button>
# <div>
# <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
# </div>
# <a class="w-7.5 h-7.5" href="/search">
# <svg class="w-full h-full">
# <use xlink:href="#n1_pupa"></use>
# </svg>
# </a>
# </div>
# </div>
# <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
# <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>
# </div>
# <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
# <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка</a>
# </div>
# </div>
# <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка
#           </a>
# </div>
# <div class="max-w-full flex py-5 border-t border-gray-2">
# <div class="flex gap-x-5 overflow-x-auto">
# <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
# </div>
# </div>
# <div class="pt-5 pb-10 border-t border-gray-2 text-18">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <section class="mb-10">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto mx-auto">
# <div class="grid grid-cols-2 col-span-2 gap-0.5 n1_m_full n1_fs_main">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=812">Партнерский материал
#                           </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=886">IT
#                           </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">4.4</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/material/2024/04/01/show-me-the-logic">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/901268/conversions/984682f01112baf608d6c672da7568c7-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/901411/conversions/137121cee0285e182cd603053629a9bb-conversion-webp.webp">
# <img alt="В чем логика?" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/901268/conversions/984682f01112baf608d6c672da7568c7-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/901411/conversions/137121cee0285e182cd603053629a9bb-conversion-webp.webp">
# <img alt="В чем логика?" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">В чем логика?</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                   Решите задачки и проверьте свой уровень логического мышления
#                 </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=908">Подкасты
#                           </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">Экология и климат
#                           </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">3.2</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/blog/2024/04/12/npluspodcast15">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/906948/conversions/f2e63fb1ec54e1305355e934b87d83a0-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/906949/conversions/910071171d491a4695d24049c4ab0570-conversion-webp.webp">
# <img alt="N + podcast: как Москва меняет климат внутри себя" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/906948/conversions/f2e63fb1ec54e1305355e934b87d83a0-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/906949/conversions/910071171d491a4695d24049c4ab0570-conversion-webp.webp">
# <img alt="N + podcast: как Москва меняет климат внутри себя" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">N + podcast: как Москва меняет климат внутри себя</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=874">Зоология
#                           </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">4.3</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/material/2024/04/05/worm-or-maggot">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/905455/conversions/afd221141303b34eb1802db044e8a57b-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/905456/conversions/cee7c875c93ac1c049f502ac3fd4119a-conversion-webp.webp">
# <img alt="От Шаи-Хулуда до опарыша" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/905455/conversions/afd221141303b34eb1802db044e8a57b-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/905456/conversions/cee7c875c93ac1c049f502ac3fd4119a-conversion-webp.webp">
# <img alt="От Шаи-Хулуда до опарыша" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">От Шаи-Хулуда до опарыша</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                   Хорошо ли вы разбираетесь в червях?
#                 </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">Экология и климат
#                           </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=874">Зоология
#                           </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/news/2024/04/17/orchid-bees">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/908446/conversions/849e788792fbd2f3837786f7f66126e3-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/908447/conversions/6321649b8b887387650c4bf15ac90a38-conversion-webp.webp">
# <img alt="Орхидных пчел назвали эффективным индикатором деградации амазонских тропиков" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/908446/conversions/849e788792fbd2f3837786f7f66126e3-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/908447/conversions/6321649b8b887387650c4bf15ac90a38-conversion-webp.webp">
# <img alt="Орхидных пчел назвали эффективным индикатором деградации амазонских тропиков" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Орхидных пчел назвали эффективным индикатором деградации амазонских тропиков</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                   Их видовое разнообразие специфически изменяется при вырубках и ведении сельского хозяйства
#                 </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-0 sm:mb-5">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9 relative">
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">16:37</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">22.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
# <p class="truncate">Зоология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.3</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/dogs-vs-tapirs">
# <div>Бродячих собак уличили в охоте на горных тапиров</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">12:47</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">22.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=876">
# <p class="truncate">Археология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.2</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/lead-mining">
# <div>Добытый в Польше свинец экспортировали в Древнюю Русь</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">12:20</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">22.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/ici-pregnancy">
# <div>Ингибиторы контрольных точек иммунитета не повысили риск патологий беременности</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">10:42</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">22.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.4</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/beta-blockers-after-infarction">
# <div>Бета-блокаторы не снизили риск смерти у пациентов с инфарктом миокарда</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">20.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.3</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/deer-and-prions">
# <div>Двух американских охотников назвали первыми возможными жертвами прионной болезни оленей среди людей</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">20.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.3</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/covid-613-days">
# <div>Ученые обнаружили новый штамм коронавируса у пациента с 613-дневным ковидом</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">20.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/watch-yourself">
# <div>Вероятность алкогольных блэкаутов связали со скоростью и продолжительностью интоксикации</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">20.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.7</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/rotavirus-wins">
# <div>Ротавирус оказался наиболее распространенным возбудителем смертельной диареи у детей</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">20.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/use-them">
# <div>Американские врачи пренебрегли новыми антибиотиками при лечении устойчивых инфекций</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/19">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">19.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=878">
# <p class="truncate">Палеонтология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/19/vasuki-indicus">
# <div>Индийские палеонтологи описали потенциально крупнейшую змею в истории. Она достигала 1115 метров в длину</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/19">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">19.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=883">
# <p class="truncate">Роботы и дроны</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.4</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1">
# <div>Робот Limx Dynamics научился по-человечески ходить по лестнице</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/19">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">19.04.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.6</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/19/pregnancy-outcomes-mortality">
# <div>Осложнения беременности повысили риск смерти от всех причин</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-0 sm:mb-10">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9">
# <div class="col-span-6">
# <div class="flex flex-col gap-x-9 border-t border-gray-2 pt-5 pb-10 sm:pb-5">
# <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/blog/2024/04/22/quantum-physics-made-me-do-it">
# <picture>
# ...
# <ul class="flex gap-3 text-gray-2">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M11 5V17"></path>
# <path d="M6.75781 6.75781L15.2431 15.2431"></path>
# <path d="M17 11L5 11"></path>
# <path d="M15.2422 6.75781L6.75691 15.2431"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle cx="25" cy="25" r="24.5"></circle>
# <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10"></path>
# </svg>
# <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
# <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625"></animate>
# </path>
# </svg>
# <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
# <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"></path>
# <path d="M13 1L1 13" stroke="#F9F9F9"></path>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd"></path>
# <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5"></rect>
# <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"></path>
# </svg>
# <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <mask id="path-1-inside-1_2694_77554">
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd"></path>
# </mask>
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd"></path>
# <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)"></path>
# </svg>
# <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# <path class="stroke-current" d="M18 35V15L36 25L18 35Z"></path>
# </svg>
# <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd"></path>
# </svg>
# <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <line stroke="#32363A" x2="30" y1="6.5" y2="6.5"></line>
# <line stroke="#32363A" x2="30" y1="23.5" y2="23.5"></line>
# <line stroke="#32363A" x2="30" y1="15" y2="15"></line>
# </svg>
# <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <path d="M4 4L26 26" stroke="#32363A"></path>
# <path d="M26 4L4 26" stroke="#32363A"></path>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
# <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"></path>
# </svg>
# <svg id="n1_specials_star" style="display:block;width:0;height:0;fill:none;stroke:white" version="1.1" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
# <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round"></path>
# </svg>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/front-build/js/app.js?id=44d98c282e99e6db71221ad7537063dd"></script>
# <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
# <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
# </body>
# </html>

# %% [markdown]
# Для просмотра выглядит не очень удобно.  «Причешем» наш `soup` – воспользуемся методом `.prettify()` в сочетании с функцией `print()`.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    N + 1 — главное издание о науке, технике и технологиях
#   </title>
#   <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
#   <link href="/front-build/css/main.css?id=9b496fbb252428c03791da99722528ab" rel="stylesheet"/>
#   <link href="/front-build/css/app.css?id=116ee51fc89adfd59429b373ba12b060" rel="stylesheet"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#f26e40" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="https://nplus1.ru" rel="canonical"/>
#   <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
#   <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');
#   </script>
#   <!-- End Google Tag Manager -->
#   <meta content="N + 1 - это научно-популярное издание, которое познакомит вас с природными явлениями, открытиями и технологиями, расскажет
#  просто о сложном и поможет узнать что-то новое для себя" name="description"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:title"/>
#   <meta content="https://nplus1.ru/images-new/share_snippet.png" property="og:image"/>
#   <meta content="https://nplus1.ru" property="og:url"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
#   <meta content="" property="og:type"/>
#   <script type="application/ld+json">
#    {
# 	"@context": "http://schema.org",
# 	"@type": "WebSite",
# 	"url": "https://nplus1.ru/",
# 	"name": "N + 1 — главное издание о науке, технике и технологиях",
# 	"description": "N + 1 — главное издание о науке, технике и технологиях",
# 	"image": "https://staticn1.nplus1.ru/image-new/share_snippet.png",
# 	"publisher": {
# 	"@type": "Organization",
# 		"name": "N+1",
# 		"logo": {
# 			"@type":"ImageObject",
# 			"url": "https://staticn1.nplus1.ru/image-new/logo-alt.png"
# 		},
# 		"sameAs": [
# 			"https://www.facebook.com/nplusone",
# 			"https://twitter.com/nplusodin",
# 			"https://vk.com/nplusone",
# 			"https://ok.ru/nplus1",
# 			"https://soundcloud.com/nplus_1",
# 			"https://t.me/nplusone"
# 		]
# 	},
# 	"potentialAction":{
# 		"@type":"SearchAction",
# 		"target":"https://nplus1.ru/search/{search_term_string}",
# 		"query-input":"required name=search_term_string"
# 	}
# }
#   </script>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@nplusodin" name="twitter:site"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:title"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
#   <meta content="https://nplus1.ru/images-new/share_snippet.png" name="twitter:image"/>
#   <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#  </head>
#  <body class="antialiased">
#   <!-- Top.Mail.Ru counter -->
#   <script type="text/javascript">
#    var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#   </script>
#   <noscript>
#    <div>
#     <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/>
#    </div>
#   </noscript>
#   <!-- /Top.Mail.Ru counter -->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
#    <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
#     <div class="border-b border-main-gray h-full">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
#       <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
#        <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
#         <svg class="w-full h-full">
#          <use xlink:href="#n1_cross_menu">
#          </use>
#         </svg>
#        </template>
#        <template v-else="">
#         <svg class="w-full h-full">
#          <use xlink:href="#n1_burger">
#          </use>
#         </svg>
#        </template>
#       </button>
#       <div>
#        <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
#       </div>
#       <a class="w-7.5 h-7.5" href="/search">
#        <svg class="w-full h-full">
#         <use xlink:href="#n1_pupa">
#         </use>
#        </svg>
#       </a>
#      </div>
#     </div>
#     <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
#        <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
#        <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">
#         N + offline
#        </a>
#        <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">
#         N + production
#        </a>
#       </div>
#       <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
#        <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#          О нас
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#          Сложность
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#          Рекламодателям
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#          Авторам
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">
#          Игры
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">
#          Физика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">
#          Зоология
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">
#          Астрономия
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">
#          Генетика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">
#          Математика
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">
#          Космонавтика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">
#          Археология
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">
#          Нейронауки
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">
#          На мышах
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">
#          Звук
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">
#          Красота
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">
#          Научные закрытия
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">
#          ИИ спешит на помощь
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">
#          Когда рассеется дым
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">
#          Книжная полка
#         </a>
#        </div>
#       </div>
#       <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
#        <ul class="flex gap-2.5">
#         <li>
#          <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tg">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#     <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#         О нас
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#         Сложность
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#         Рекламодателям
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#         Авторам
#        </a>
#       </div>
#       <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">
#         Игры
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">
#         Физика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">
#         Зоология
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">
#         Астрономия
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">
#         Генетика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">
#         Математика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">
#         Космонавтика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">
#         Археология
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">
#         Нейронауки
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">
#         На мышах
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">
#         Звук
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">
#         Красота
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">
#         Научные закрытия
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">
#         ИИ спешит на помощь
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">
#         Когда рассеется дым
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">
#         Книжная полка
#        </a>
#       </div>
#       <div class="max-w-full flex py-5 border-t border-gray-2">
#        <div class="flex gap-x-5 overflow-x-auto">
#         <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">
#          N + offline
#         </a>
#         <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">
#          N + production
#         </a>
#        </div>
#       </div>
#       <div class="pt-5 pb-10 border-t border-gray-2 text-18">
#        <ul class="flex gap-2.5">
#         <li>
#          <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_tg">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#    </header>
#    <section class="mb-10">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto mx-auto">
#      <div class="grid grid-cols-2 col-span-2 gap-0.5 n1_m_full n1_fs_main">
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=812">
#           Партнерский материал
#          </a>
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=886">
#           IT
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            4.4
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/material/2024/04/01/show-me-the-logic">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/901268/conversions/984682f01112baf608d6c672da7568c7-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/901411/conversions/137121cee0285e182cd603053629a9bb-conversion-webp.webp">
#               <img alt="В чем логика?" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/901268/conversions/984682f01112baf608d6c672da7568c7-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/901411/conversions/137121cee0285e182cd603053629a9bb-conversion-webp.webp">
#               <img alt="В чем логика?" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            В чем логика?
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Решите задачки и проверьте свой уровень логического мышления
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=908">
#           Подкасты
#          </a>
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">
#           Экология и климат
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            3.2
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/blog/2024/04/12/npluspodcast15">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/906948/conversions/f2e63fb1ec54e1305355e934b87d83a0-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/906949/conversions/910071171d491a4695d24049c4ab0570-conversion-webp.webp">
#               <img alt="N + podcast: как Москва меняет климат внутри себя" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/906948/conversions/f2e63fb1ec54e1305355e934b87d83a0-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/906949/conversions/910071171d491a4695d24049c4ab0570-conversion-webp.webp">
#               <img alt="N + podcast: как Москва меняет климат внутри себя" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            N + podcast: как Москва меняет климат внутри себя
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=874">
#           Зоология
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            4.3
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/material/2024/04/05/worm-or-maggot">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/905455/conversions/afd221141303b34eb1802db044e8a57b-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/905456/conversions/cee7c875c93ac1c049f502ac3fd4119a-conversion-webp.webp">
#               <img alt="От Шаи-Хулуда до опарыша" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/905455/conversions/afd221141303b34eb1802db044e8a57b-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/905456/conversions/cee7c875c93ac1c049f502ac3fd4119a-conversion-webp.webp">
#               <img alt="От Шаи-Хулуда до опарыша" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            От Шаи-Хулуда до опарыша
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Хорошо ли вы разбираетесь в червях?
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">
#           Экология и климат
#          </a>
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=874">
#           Зоология
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            1.9
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/news/2024/04/17/orchid-bees">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/908446/conversions/849e788792fbd2f3837786f7f66126e3-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/908447/conversions/6321649b8b887387650c4bf15ac90a38-conversion-webp.webp">
#               <img alt="Орхидных пчел назвали эффективным индикатором деградации амазонских тропиков" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/908446/conversions/849e788792fbd2f3837786f7f66126e3-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/908447/conversions/6321649b8b887387650c4bf15ac90a38-conversion-webp.webp">
#               <img alt="Орхидных пчел назвали эффективным индикатором деградации амазонских тропиков" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            Орхидных пчел назвали эффективным индикатором деградации амазонских тропиков
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Их видовое разнообразие специфически изменяется при вырубках и ведении сельского хозяйства
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#      </div>
#     </div>
#    </section>
#    <section class="mb-0 sm:mb-5">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9 relative">
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            16:37
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            22.04.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#           <p class="truncate">
#            Зоология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.3
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/dogs-vs-tapirs">
#          <div>
#           Бродячих собак уличили в охоте на горных тапиров
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            12:47
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            22.04.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=876">
#           <p class="truncate">
#            Археология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            3.2
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/lead-mining">
#          <div>
#           Добытый в Польше свинец экспортировали в Древнюю Русь
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            12:20
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            22.04.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.9
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/ici-pregnancy">
#          <div>
#           Ингибиторы контрольных точек иммунитета не повысили риск патологий беременности
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            10:42
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            22.04.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.4
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/beta-blockers-after-infarction">
#          <div>
#           Бета-блокаторы не снизили риск смерти у пациентов с инфарктом миокарда
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            20.04.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            4.3
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/deer-and-prions">
#          <div>
#           Двух американских охотников назвали первыми возможными жертвами прионной болезни оленей среди людей
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            20.04.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.3
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/covid-613-days">
#          <div>
#           Ученые обнаружили новый штамм коронавируса у пациента с 613-дневным ковидом
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            20.04.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.1
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/watch-yourself">
#          <div>
#           Вероятность алкогольных блэкаутов связали со скоростью и продолжительностью интоксикации
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            20.04.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.7
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/rotavirus-wins">
#          <div>
#           Ротавирус оказался наиболее распространенным возбудителем смертельной диареи у детей
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
# ...
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#    <path d="M11 5V17">
#    </path>
#    <path d="M6.75781 6.75781L15.2431 15.2431">
#    </path>
#    <path d="M17 11L5 11">
#    </path>
#    <path d="M15.2422 6.75781L6.75691 15.2431">
#    </path>
#   </svg>
#   <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <circle cx="25" cy="25" r="24.5">
#    </circle>
#    <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#    <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
#     <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625">
#     </animate>
#    </path>
#   </svg>
#   <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
#    <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9">
#    </path>
#    <path d="M13 1L1 13" stroke="#F9F9F9">
#    </path>
#   </svg>
#   <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#    <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor">
#    </path>
#   </svg>
#   <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd">
#    </path>
#    <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z">
#    </path>
#   </svg>
#   <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5">
#    </rect>
#    <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <mask id="path-1-inside-1_2694_77554">
#     <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd">
#     </path>
#    </mask>
#    <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd">
#    </path>
#    <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#    <path class="stroke-current" d="M18 35V15L36 25L18 35Z">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
#    <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <line stroke="#32363A" x2="30" y1="6.5" y2="6.5">
#    </line>
#    <line stroke="#32363A" x2="30" y1="23.5" y2="23.5">
#    </line>
#    <line stroke="#32363A" x2="30" y1="15" y2="15">
#    </line>
#   </svg>
#   <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <path d="M4 4L26 26" stroke="#32363A">
#    </path>
#    <path d="M26 4L4 26" stroke="#32363A">
#    </path>
#   </svg>
#   <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
#    <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z">
#    </path>
#   </svg>
#   <svg id="n1_specials_star" style="display:block;width:0;height:0;fill:none;stroke:white" version="1.1" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#    <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round">
#    </path>
#   </svg>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script src="/front-build/js/app.js?id=44d98c282e99e6db71221ad7537063dd">
#   </script>
#   <!-- Yandex.Metrika counter 2-->
#   <script type="text/javascript">
#    (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
#   </script>
#   <noscript>
#    <div>
#     <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
#     <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
#    </div>
#   </noscript>
#   <!-- /Yandex.Metrika counter -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
#   </script>
#   <script>
#    window.yaContextCb = window.yaContextCb || []
#   </script>
#   <script async="" src="https://yandex.ru/ads/system/context.js">
#   </script>
#   <script>
#    if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
#   </script>
#  </body>
# </html>

# %% [markdown]
# В такой выдаче ориентироваться гораздо удобнее (но при желании, то же можно увидеть в браузере, на большом экране).

# %% [markdown]
# Чтобы сгрузить все новости с главной страницы сайта, нужно собрать все ссылки на страницы с этими новостями. Ссылки в html-файле всегда заключены в тэг `<a></a>` и имеют атрибут `href`.
#
# **Функция `soup.find('a')`** найдет первый в дереве тег \<a>.
# Если нам нужно найти не только первый элемент, а все элементы по определенному признаку, следует использовать функцию **`soup.find_all('a')`**

# %%
soup.find_all('a')
# Out:
# [<a class="w-7.5 h-7.5" href="/search">
#  <svg class="w-full h-full">
#  <use xlink:href="#n1_pupa"></use>
#  </svg>
#  </a>,
#  <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>,
#  <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                  О нас
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                  Сложность
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                  Рекламодателям
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                  Авторам
#                </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка</a>,
#  <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tg"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_vk"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_ok"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tw"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                  О нас
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                  Сложность
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                  Рекламодателям
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                  Авторам
#                </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка
#            </a>,
#  <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>,
#  <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>,
#  <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_tg"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_vk"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_ok"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_tw"></use>
#  </svg>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=812">Партнерский материал
#                            </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=886">IT
#                            </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">4.4</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/material/2024/04/01/show-me-the-logic">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/901268/conversions/984682f01112baf608d6c672da7568c7-conversion-webp.webp">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/901411/conversions/137121cee0285e182cd603053629a9bb-conversion-webp.webp">
#  <img alt="В чем логика?" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/901268/conversions/984682f01112baf608d6c672da7568c7-conversion-webp.webp">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/901411/conversions/137121cee0285e182cd603053629a9bb-conversion-webp.webp">
#  <img alt="В чем логика?" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">В чем логика?</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                    Решите задачки и проверьте свой уровень логического мышления
#                  </div>
#  </div>
#  </div>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=908">Подкасты
#                            </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">Экология и климат
#                            </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">3.2</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/blog/2024/04/12/npluspodcast15">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/906948/conversions/f2e63fb1ec54e1305355e934b87d83a0-conversion-webp.webp">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/906949/conversions/910071171d491a4695d24049c4ab0570-conversion-webp.webp">
#  <img alt="N + podcast: как Москва меняет климат внутри себя" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/906948/conversions/f2e63fb1ec54e1305355e934b87d83a0-conversion-webp.webp">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/906949/conversions/910071171d491a4695d24049c4ab0570-conversion-webp.webp">
#  <img alt="N + podcast: как Москва меняет климат внутри себя" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">N + podcast: как Москва меняет климат внутри себя</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#  </div>
#  </div>
#  </div>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=874">Зоология
#                            </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">4.3</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/material/2024/04/05/worm-or-maggot">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/905455/conversions/afd221141303b34eb1802db044e8a57b-conversion-webp.webp">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/905456/conversions/cee7c875c93ac1c049f502ac3fd4119a-conversion-webp.webp">
#  <img alt="От Шаи-Хулуда до опарыша" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/905455/conversions/afd221141303b34eb1802db044e8a57b-conversion-webp.webp">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/905456/conversions/cee7c875c93ac1c049f502ac3fd4119a-conversion-webp.webp">
#  <img alt="От Шаи-Хулуда до опарыша" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">От Шаи-Хулуда до опарыша</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                    Хорошо ли вы разбираетесь в червях?
#                  </div>
#  </div>
#  </div>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">Экология и климат
#                            </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=874">Зоология
#                            </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/news/2024/04/17/orchid-bees">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/908446/conversions/849e788792fbd2f3837786f7f66126e3-conversion-webp.webp">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/908447/conversions/6321649b8b887387650c4bf15ac90a38-conversion-webp.webp">
#  <img alt="Орхидных пчел назвали эффективным индикатором деградации амазонских тропиков" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/908446/conversions/849e788792fbd2f3837786f7f66126e3-conversion-webp.webp">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/908447/conversions/6321649b8b887387650c4bf15ac90a38-conversion-webp.webp">
#  <img alt="Орхидных пчел назвали эффективным индикатором деградации амазонских тропиков" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Орхидных пчел назвали эффективным индикатором деградации амазонских тропиков</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                    Их видовое разнообразие специфически изменяется при вырубках и ведении сельского хозяйства
#                  </div>
#  </div>
#  </div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">22.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#  <p class="truncate">Зоология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.3</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/dogs-vs-tapirs">
#  <div>Бродячих собак уличили в охоте на горных тапиров</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">22.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=876">
#  <p class="truncate">Археология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.2</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/lead-mining">
#  <div>Добытый в Польше свинец экспортировали в Древнюю Русь</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">22.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/ici-pregnancy">
#  <div>Ингибиторы контрольных точек иммунитета не повысили риск патологий беременности</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/22">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">22.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.4</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/22/beta-blockers-after-infarction">
#  <div>Бета-блокаторы не снизили риск смерти у пациентов с инфарктом миокарда</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">20.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.3</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/deer-and-prions">
#  <div>Двух американских охотников назвали первыми возможными жертвами прионной болезни оленей среди людей</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">20.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.3</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/covid-613-days">
#  <div>Ученые обнаружили новый штамм коронавируса у пациента с 613-дневным ковидом</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">20.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.1</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/watch-yourself">
#  <div>Вероятность алкогольных блэкаутов связали со скоростью и продолжительностью интоксикации</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">20.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.7</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/rotavirus-wins">
#  <div>Ротавирус оказался наиболее распространенным возбудителем смертельной диареи у детей</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/20">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">20.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.1</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/20/use-them">
#  <div>Американские врачи пренебрегли новыми антибиотиками при лечении устойчивых инфекций</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/19">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">19.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=878">
#  <p class="truncate">Палеонтология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.1</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/19/vasuki-indicus">
#  <div>Индийские палеонтологи описали потенциально крупнейшую змею в истории. Она достигала 1115 метров в длину</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/19">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">19.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=883">
#  <p class="truncate">Роботы и дроны</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.4</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1">
#  <div>Робот Limx Dynamics научился по-человечески ходить по лестнице</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/19">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">19.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.6</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/19/pregnancy-outcomes-mortality">
#  <div>Осложнения беременности повысили риск смерти от всех причин</div>
#  </a>,
#  <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/blog/2024/04/22/quantum-physics-made-me-do-it">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/909747/conversions/66265367f039f_cover_mobile-conversion-webp.webp">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/909746/conversions/66265366c1fb2_cover_tablet-conversion-webp.webp">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/909745/conversions/66265365ba05c_cover-conversion-webp.webp">
#  <img alt="«Это все квантовая физика! Непочтительное руководство по фундаментальной природе всего»" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/909745/conversions/66265365ba05c_cover-conversion-webp.webp"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/blog/2024/04/22">
#  <span class="group-hover:text-main transition-colors duration-75">22.04.24</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=869">
#  <span class="group-hover:text-main transition-colors duration-75">Физика</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/blog/2024/04/22/quantum-physics-made-me-do-it">
#  <h3 class="text-34 sm:text-22 lg:text-32 mb-1 transition-colors duration-75 group-hover:text-main">
#                  «Это все квантовая физика! Непочтительное руководство по фундаментальной природе всего»</h3>
#  <p class="font-spectral text-main-gray text-36 sm:text-24 lg:text-34 transition-colors duration-75 group-hover:text-main">
#                  Как теория Дэвида Бома отрицает свободу воли</p>
#  </a>,
#  <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/blog/2024/04/19/misbelief">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/908731/conversions/6620ce2f3125c_cover_mobile-conversion-webp.webp">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/908730/conversions/6620ce2e0fb85_cover_tablet-conversion-webp.webp">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/908729/conversions/6620ce2cefee8_cover-conversion-webp.webp">
#  <img alt="«Время заблуждений: Почему умные люди поддаются фальсификациям, распространяют слухи и верят в теории заговора»" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/908729/conversions/6620ce2cefee8_cover-conversion-webp.webp"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/blog/2024/04/19">
#  <span class="group-hover:text-main transition-colors duration-75">19.04.24</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=882">
#  <span class="group-hover:text-main transition-colors duration-75">Психология</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/blog/2024/04/19/misbelief">
#  <h3 class="text-34 sm:text-22 lg:text-32 mb-1 transition-colors duration-75 group-hover:text-main">
#                  «Время заблуждений: Почему умные люди поддаются фальсификациям, распространяют слухи и верят в теории заговора»</h3>
#  <p class="font-spectral text-main-gray text-36 sm:text-24 lg:text-34 transition-colors duration-75 group-hover:text-main">
#                  Что такое мотивированное рассуждение</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/19">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">19.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=870">
#  <p class="truncate">Химия</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.4</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/19/para-to-meta-phenols">
#  <div>Фенолы изомеризовались в три стадии</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/19">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">19.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.6</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/19/mental-health-homelessness">
#  <div>Две трети бездомных пострадали от ментальных расстройств</div>
#  </a>,
#  <a class="w-full h-44 group relative" href="https://nplus1.ru/material/2024/02/14/wild-pick-up">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/886449/conversions/19ca8dd326964bc977882181d67a740a-conversion-webp.webp">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/886449/conversions/19ca8dd326964bc977882181d67a740a-conversion-webp.webp">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/886448/conversions/03e74642d4ad6551252052d4ed0031c3-conversion-webp.webp">
#  <img alt="Восемь самок" class="w-full h-full object-cover z-10" loading="lazy" src="https://minio.nplus1.ru/app-images/886448/conversions/03e74642d4ad6551252052d4ed0031c3-conversion-webp.webp"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/2024/02/14">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">14.02.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#  <p class="truncate">Зоология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.1</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/material/2024/02/14/wild-pick-up">
#  <div>Восемь самок</div>
#  <div class="text-main-gray">Соблазните пернатых, шестиногих и чешуйчатых женщин</div>
#  </a>,
#  <a class="shrink-0 absolute inset-0 group" href="https://nplus1.ru/material/2024/02/07/izucat-izobretat-i-otkryvat">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/885404/conversions/9b59283fd5729ef2620b497ad38574f6-conversion-webp.webp">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/885403/conversions/46493c93e4d367131c0c5d8b3c4aca51-conversion-webp.webp">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/885403/conversions/46493c93e4d367131c0c5d8b3c4aca51-conversion-webp.webp">
#  <img alt="Изучать, изобретать и открывать" class="w-full h-full object-cover absolute inset-0 brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=812">
#  <span class="group-hover:text-main transition-colors duration-75">Партнерский материал</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">1.4</span>
#  </a>,
#  <a class="group text-white absolute bottom-5 inset-x-6 md:inset-x-5" href="https://nplus1.ru/material/2024/02/07/izucat-izobretat-i-otkryvat">
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#            Изучать, изобретать и открывать
#          </p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/blog/2024/04/17">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">17.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=869">
#  <p class="truncate">Физика</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.1</span>
#  </a>,
#  <a class="flex flex-col text-14 overflow-hidden" href="/author/bombora">
#  <div class="mb-0.5 max-w-full whitespace-nowrap overflow-hidden text-ellipsis">
#
#                                  «Бомбора»
#                </div>
#  <div class="font-spectral max-w-full whitespace-nowrap overflow-hidden text-ellipsis">
#                  Книжное издательство
#                </div>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/blog/2024/04/17/helgoland">
#  <div>«Гельголанд. Красивая и странная квантовая физика»</div>
#  <div class="text-main-gray">Почему для понимания природы важно взаимовлияние физических систем</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/04/19">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">19.04.24</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=872">
#  <p class="truncate">Экология и климат</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/04/19/upwelling-killed-megafauna">
# ...
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=883">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Роботы и дроны
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            2.4
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2024/04/12/hopcopter">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Одноногий квадрокоптер подпрыгнул вверх на полтора метра</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              И развил рекордную скорость 2,38 метра в секунду</p>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/03/28">
#  <span class="group-hover:text-main transition-colors duration-75">28.03.24</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=877">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Антропология
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            3.5
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2024/03/28/emperor-wu">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Палеогенетики прочитали геном императора У-ди</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              Он правил государством Северная Чжоу в VI веке нашей эры</p>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/blog/2024/04/17">
#  <span class="group-hover:text-main transition-colors duration-75">17.04.24</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=869">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Физика
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            1.1
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/blog/2024/04/17/helgoland">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            «Гельголанд. Красивая и странная квантовая физика»</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              Почему для понимания природы важно взаимовлияние физических систем</p>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/04/05">
#  <span class="group-hover:text-main transition-colors duration-75">05.04.24</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=872">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Экология и климат
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            1.9
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2024/04/05/yellowstone-tourism-emissions">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Туризм в Йеллоустоуне оказался причиной выброса миллиона тонн углекислого газа в год</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              65 процентов этих выбросов приходится на авиаперелеты</p>
#  </a>,
#  <a class="absolute inset-0 md:static order-2 shrink-0 brightness-50 md:brightness-100" href="https://nplus1.ru/blog/2024/04/03/exclusome">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/904261/conversions/8a8bb639efc73f508d5cbe76ff507a6d-conversion-webp.webp">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/904261/conversions/8a8bb639efc73f508d5cbe76ff507a6d-conversion-webp.webp">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/904258/conversions/2d3c16fb95a7b8c7e07e14c383bfb68a-conversion-webp.webp">
#  <img alt="Коллекционер ДНК" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/904258/conversions/2d3c16fb95a7b8c7e07e14c383bfb68a-conversion-webp.webp"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/blog/2024/04/03">
#  <span class="group-hover:text-main transition-colors duration-75">03.04.24</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=885">
#  <span class="group-hover:text-main transition-colors duration-75">Биология</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=900">
#  <span class="group-hover:text-main transition-colors duration-75">Блоги</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/7">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">7.2</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/blog/2024/04/03/exclusome">
#  <h3 class="text-34 lg:text-44 mb-1 transition-colors duration-75 group-hover:text-main">
#                  Коллекционер ДНК</h3>
#  <p class="text-white md:text-main-gray font-spectral text-36 lg:text-46 transition-colors duration-75 group-hover:text-main">
#                  Как биологи открыли эксклюсому — новую структуру в клетках млекопитающих</p>
#  </a>,
#  <a class="absolute inset-0 md:static order-2 md:order-1 shrink-0 brightness-50 md:brightness-100" href="https://nplus1.ru/material/2024/02/22/put-cigarettes-out">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/886517/conversions/f827e31685249114a07cec531c282609-conversion-webp.webp">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/886517/conversions/f827e31685249114a07cec531c282609-conversion-webp.webp">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/886514/conversions/30a11369c0664725d451c587debc2a3c-conversion-webp.webp">
#  <img alt="Туши сигарету" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/886514/conversions/30a11369c0664725d451c587debc2a3c-conversion-webp.webp"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/2024/02/22">
#  <span class="group-hover:text-main transition-colors duration-75">22.02.24</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=812">
#  <span class="group-hover:text-main transition-colors duration-75">Партнерский материал</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">3.3</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/material/2024/02/22/put-cigarettes-out">
#  <h3 class="text-34 lg:text-44 mb-1 transition-colors duration-75 group-hover:text-main">
#                  Туши сигарету</h3>
#  <p class="text-white md:text-main-gray font-spectral text-36 lg:text-46 transition-colors duration-75 group-hover:text-main">
#                  Как и почему менялись привычки употребления табака</p>
#  </a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/02/mirror-image-cyclodextrins">
#                Химики синтезировали неприродные энантиомеры циклодекстринов</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/02/asassn-20qc">
#                Черная дыра промежуточной массы выдала себя пролетами сквозь аккреционный поток вблизи сверхмассивной черной дыры</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/03/photons-to-tau">
#                Два фотона превратились в два тау-лептона в протон-протонных столкновениях</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/blog/2024/04/03/exclusome">
#                Коллекционер ДНК</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/05/gan-microring-single-photon-source">
#                Кольцо из нитрида галлия превратили в источник одиночных фотонов</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/06/gw-bh-ns-or-no">
#                Обсерватория LIGO увидела слияние нейтронной звезды и рекордно легкой черной дыры</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/10/neutrino-ignored-quantum-gravity">
#                На нейтрино не подействовала квантовая гравитация</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/11/rotaxane-actuator">
#                Ротаксан разгрузил молекулы в ответ на приложение силы</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/12/magnetic-and-mergers">
#                Замагниченность массивной звезды объяснили слиянием звезд в тройной системе</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/15/bread-dark-photons">
#                Физики не увидели темных фотонов от темной материи</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/16/boat-sn">
#                Самый яркий гамма-всплеск породил очень мало тяжелых элементов</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/18/sympalamprey">
#                У миног нашли зачатки симпатической нервной системы</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/18/ultrafast-kapitza-dirac">
#                Физики увидели сверхбыстрый эффект Капицы — Дирака</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/18/goldene-synthesis">
#                Химики синтезировали голден</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2024/04/18/jwst-w-1935">
#                «Джеймс Уэбб» заметил нагрев стратосферы холодного коричневого карлика полярными сияниями</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/about" target="_blank">О нас</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/difficult" target="_blank">Сложность</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/adv" target="_blank">Рекламодателям</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">Авторам</a>,
#  <a href="/cdn-cgi/l/email-protection#fe9092be908e928b8dcfd08c8b"><span class="__cf_email__" data-cfemail="e08e8ca08e908c9593d1ce9295">[email protected]</span></a>,
#  <a href="/cdn-cgi/l/email-protection#d0b9beb6bf90bea0bca5a3e1fea2a5"><span class="__cf_email__" data-cfemail="a0c9cec6cfe0ced0ccd5d3918ed2d5">[email protected]</span></a>,
#  <a class="underline transition-colors duration-75 hover:text-main inline-block col-span-6 sm:col-span-5 mb-5 font-spectral italic" href="/personal-data-policy">Политика
#            обработки
#            персональных данных пользователей сайта
#          </a>,
#  <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tg"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_vk"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_ok"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tw"></use>
#  </svg>
#  </a>]

# %%
len(soup.find_all('a'))
# Out:
# 439

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /search
# https://offline.nplus1.ru/
# https://nplus.pro/
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# https://nplus1.ru/search?tags=946
# https://nplus1.ru/search?tags=869
# https://nplus1.ru/search?tags=874
# https://nplus1.ru/search?tags=880
# https://nplus1.ru/search?tags=768
# https://nplus1.ru/search?tags=890
# https://nplus1.ru/search?tags=871
# https://nplus1.ru/search?tags=876
# https://nplus1.ru/search?tags=775
# https://nplus1.ru/search?tags=767
# https://nplus1.ru/search?tags=771
# https://nplus1.ru/search?tags=772
# https://nplus1.ru/search?tags=778
# https://nplus1.ru/search?tags=917
# https://nplus1.ru/search?tags=918
# https://nplus1.ru/search?tags=824
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# https://nplus1.ru/search?tags=946
# https://nplus1.ru/search?tags=869
# https://nplus1.ru/search?tags=874
# https://nplus1.ru/search?tags=880
# https://nplus1.ru/search?tags=768
# https://nplus1.ru/search?tags=890
# https://nplus1.ru/search?tags=871
# https://nplus1.ru/search?tags=876
# https://nplus1.ru/search?tags=775
# https://nplus1.ru/search?tags=767
# https://nplus1.ru/search?tags=771
# https://nplus1.ru/search?tags=772
# https://nplus1.ru/search?tags=778
# https://nplus1.ru/search?tags=917
# https://nplus1.ru/search?tags=918
# https://nplus1.ru/search?tags=824
# https://offline.nplus1.ru/
# https://nplus.pro/
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin
# https://nplus1.ru/search?tags=812
# https://nplus1.ru/search?tags=886
# /material/difficulty/4
# https://nplus1.ru/material/2024/04/01/show-me-the-logic
# https://nplus1.ru/search?tags=908
# https://nplus1.ru/search?tags=872
# /material/difficulty/3
# https://nplus1.ru/blog/2024/04/12/npluspodcast15
# https://nplus1.ru/search?tags=874
# /material/difficulty/4
# https://nplus1.ru/material/2024/04/05/worm-or-maggot
# https://nplus1.ru/search?tags=872
# https://nplus1.ru/search?tags=874
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/17/orchid-bees
# /news/2024/04/22
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/22/dogs-vs-tapirs
# /news/2024/04/22
# https://nplus1.ru/search?tags=876
# /material/difficulty/3
# https://nplus1.ru/news/2024/04/22/lead-mining
# /news/2024/04/22
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/22/ici-pregnancy
# /news/2024/04/22
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/22/beta-blockers-after-infarction
# /news/2024/04/20
# https://nplus1.ru/search?tags=873
# /material/difficulty/4
# https://nplus1.ru/news/2024/04/20/deer-and-prions
# /news/2024/04/20
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/20/covid-613-days
# /news/2024/04/20
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/20/watch-yourself
# /news/2024/04/20
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/20/rotavirus-wins
# /news/2024/04/20
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/20/use-them
# /news/2024/04/19
# https://nplus1.ru/search?tags=878
# /material/difficulty/4
# https://nplus1.ru/news/2024/04/19/vasuki-indicus
# /news/2024/04/19
# https://nplus1.ru/search?tags=883
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1
# /news/2024/04/19
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/19/pregnancy-outcomes-mortality
# https://nplus1.ru/blog/2024/04/22/quantum-physics-made-me-do-it
# /blog/2024/04/22
# https://nplus1.ru/search?tags=869
# /material/difficulty/1
# https://nplus1.ru/blog/2024/04/22/quantum-physics-made-me-do-it
# https://nplus1.ru/blog/2024/04/19/misbelief
# /blog/2024/04/19
# https://nplus1.ru/search?tags=882
# /material/difficulty/1
# https://nplus1.ru/blog/2024/04/19/misbelief
# /news/2024/04/19
# https://nplus1.ru/search?tags=870
# /material/difficulty/3
# https://nplus1.ru/news/2024/04/19/para-to-meta-phenols
# /news/2024/04/19
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/19/mental-health-homelessness
# https://nplus1.ru/material/2024/02/14/wild-pick-up
# /material/2024/02/14
# https://nplus1.ru/search?tags=874
# /material/difficulty/3
# https://nplus1.ru/material/2024/02/14/wild-pick-up
# https://nplus1.ru/material/2024/02/07/izucat-izobretat-i-otkryvat
# https://nplus1.ru/search?tags=812
# /material/difficulty/1
# https://nplus1.ru/material/2024/02/07/izucat-izobretat-i-otkryvat
# /blog/2024/04/17
# https://nplus1.ru/search?tags=869
# /material/difficulty/1
# /author/bombora
# https://nplus1.ru/blog/2024/04/17/helgoland
# /news/2024/04/19
# https://nplus1.ru/search?tags=872
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/19/upwelling-killed-megafauna
# /news/2024/04/19
# https://nplus1.ru/search?tags=876
# /material/difficulty/3
# https://nplus1.ru/news/2024/04/19/incised-bear-bone
# /news/2024/04/19
# https://nplus1.ru/search?tags=874
# /material/difficulty/3
# https://nplus1.ru/news/2024/04/19/bombus-impatiens-flooding
# https://nplus1.ru/material/2024/02/05/russian-op-future
# /material/2024/02/05
# https://nplus1.ru/search?tags=812
# /material/difficulty/1
# https://nplus1.ru/material/2024/02/05/russian-op-future
# /news/2024/04/19
# https://nplus1.ru/search?tags=877
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/19/mandible-in-travertin-floor
# /news/2024/04/19
# https://nplus1.ru/search?tags=876
# /material/difficulty/3
# https://nplus1.ru/news/2024/04/19/three-stelae
# https://nplus1.ru/material/2024/01/30/outstanding-op-software
# /material/2024/01/30
# https://nplus1.ru/search?tags=812
# /material/difficulty/1
# https://nplus1.ru/material/2024/01/30/outstanding-op-software
# https://nplus1.ru/material/2024/01/22/risk-modification
# https://nplus1.ru/search?tags=812
# /material/difficulty/2
# https://nplus1.ru/material/2024/01/22/risk-modification
# /blog/2024/04/08
# https://nplus1.ru/search?tags=877
# /material/difficulty/1
# /author/nlo
# https://nplus1.ru/blog/2024/04/08/khrushchevka
# /news/2024/04/19
# https://nplus1.ru/search?tags=873
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/19/no-more-airborne
# /news/2024/04/19
# https://nplus1.ru/search?tags=873
# /material/difficulty/4
# https://nplus1.ru/news/2024/04/19/global-burden-all-diseases
# /news/2024/04/18
# https://nplus1.ru/search?tags=880
# /material/difficulty/4
# https://nplus1.ru/news/2024/04/18/jwst-w-1935
# https://nplus1.ru/material/2024/01/06/metamorphoses
# /material/2024/01/06
# https://nplus1.ru/search?tags=874
# /material/difficulty/4
# https://nplus1.ru/material/2024/01/06/metamorphoses
# /news/2024/04/18
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/18/antipsychotic-use-adverse-outcomes
# /news/2024/04/18
# https://nplus1.ru/search?tags=871
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/18/hayabusa-2-off-mode
# https://nplus1.ru/material/2024/01/05/abies
# /material/2024/01/05
# https://nplus1.ru/search?tags=889
# /material/difficulty/2
# https://nplus1.ru/material/2024/01/05/abies
# https://nplus1.ru/material/2024/01/04/new-year-blues
# https://nplus1.ru/search?tags=882
# /material/difficulty/4
# https://nplus1.ru/material/2024/01/04/new-year-blues
# /blog/2024/04/05
# https://nplus1.ru/search?tags=878
# /material/difficulty/1
# /author/bombora
# https://nplus1.ru/blog/2024/04/05/why-didnt-giraffes-become-human
# /news/2024/04/18
# https://nplus1.ru/search?tags=870
# /material/difficulty/5
# https://nplus1.ru/news/2024/04/18/goldene-synthesis
# /news/2024/04/18
# https://nplus1.ru/search?tags=871
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/18/dragonfly-go
# /news/2024/04/18
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/18/birds-babbling
# https://nplus1.ru/material/2024/01/02/wild-home-alone
# /material/2024/01/02
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/material/2024/01/02/wild-home-alone
# /news/2024/04/18
# https://nplus1.ru/search?tags=883
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/18/three-legged-chair-robot
# /news/2024/04/18
# https://nplus1.ru/search?tags=871
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/18/ingenuity-will-work-until-death
# https://nplus1.ru/material/2024/01/01/citrus-evolution
# /material/2024/01/01
# https://nplus1.ru/search?tags=889
# /material/difficulty/4
# https://nplus1.ru/material/2024/01/01/citrus-evolution
# https://nplus1.ru/material/2023/12/30/new-year-socks
# https://nplus1.ru/search?tags=881
# /material/difficulty/4
# https://nplus1.ru/material/2023/12/30/new-year-socks
# /blog/2024/04/03
# https://nplus1.ru/search?tags=817
# /material/difficulty/1
# /author/kolibri
# https://nplus1.ru/blog/2024/04/03/the-world-of-sugar
# /news/2024/04/18
# https://nplus1.ru/search?tags=869
# /material/difficulty/7
# https://nplus1.ru/news/2024/04/18/ultrafast-kapitza-dirac
# /news/2024/04/18
# https://nplus1.ru/search?tags=876
# /material/difficulty/3
# https://nplus1.ru/news/2024/04/18/maya-ucanal
# /news/2024/04/18
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/18/blue-tits-siring-success
# https://nplus1.ru/material/2023/12/28/series-therapy
# /material/2023/12/28
# https://nplus1.ru/search?tags=812
# /material/difficulty/3
# https://nplus1.ru/material/2023/12/28/series-therapy
# /news/2024/04/18
# https://nplus1.ru/search?tags=874
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/18/wisdom-coquetry
# /news/2024/04/18
# https://nplus1.ru/search?tags=873
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/18/narcosis-rules
# https://nplus1.ru/material/2023/12/28/mind-crib
# /material/2023/12/28
# https://nplus-1.ru/search?tags=885
# /material/difficulty/5
# https://nplus1.ru/material/2023/12/28/mind-crib
# https://nplus1.ru/material/2023/12/27/new-years-commotion
# https://nplus1.ru/search?tags=812
# /material/difficulty/5
# https://nplus1.ru/material/2023/12/27/new-years-commotion
# /blog/2024/04/01
# https://nplus1.ru/search?tags=885
# /material/difficulty/1
# /author/alpina-non-fiksn
# https://nplus1.ru/blog/2024/04/01/the-genesis-machine
# /news/2024/04/18
# https://nplus1.ru/search?tags=885
# /material/difficulty/6
# https://nplus1.ru/news/2024/04/18/sympalamprey
# /news/2024/04/18
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/18/aortic-coarctation
# /news/2024/04/17
# https://nplus1.ru/search?tags=874
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/17/gymnogyps-californianus-egg
# https://nplus1.ru/material/2023/12/26/yandex-delivery-robot
# /material/2023/12/26
# https://nplus1.ru/search?tags=812
# /material/difficulty/2
# https://nplus1.ru/material/2023/12/26/yandex-delivery-robot
# /news/2024/04/09
# https://nplus1.ru/search?tags=874
# /material/difficulty/4
# https://nplus1.ru/news/2024/04/09/cannibalism-in-hoopoes
# /news/2024/04/15
# https://nplus1.ru/search?tags=876
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/15/shipwreck-of-ses-fontanelles
# /news/2024/03/27
# https://nplus1.ru/search?tags=870
# /material/difficulty/4
# https://nplus1.ru/news/2024/03/27/taste-of-beer
# /news/2024/04/18
# https://nplus1.ru/search?tags=874
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/18/wisdom-coquetry
# /news/2024/04/03
# https://nplus1.ru/search?tags=885
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/03/the-speed-of-sight
# /news/2024/04/12
# https://nplus1.ru/search?tags=870
# /material/difficulty/3
# https://nplus1.ru/news/2024/04/12/zeolite-for-pe
# /news/2024/04/19
# https://nplus1.ru/search?tags=878
# /material/difficulty/4
# https://nplus1.ru/news/2024/04/19/vasuki-indicus
# /news/2022/01/25
# https://nplus1.ru/search?tags=873
# https://nplus1.ru/search?tags=766
# /material/difficulty/3
# https://nplus1.ru/news/2022/01/25/coronavirus-survivial
# /news/2024/03/27
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/news/2024/03/27/javan-tiger
# /news/2024/04/02
# https://nplus1.ru/search?tags=880
# /material/difficulty/4
# https://nplus1.ru/news/2024/04/02/asassn-20qc
# /news/2024/04/15
# https://nplus1.ru/search?tags=877
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/15/mummified-egyptian-head
# /news/2024/04/10
# https://nplus1.ru/search?tags=869
# /material/difficulty/5
# https://nplus1.ru/news/2024/04/10/neutrino-ignored-quantum-gravity
# /news/2024/04/18
# https://nplus1.ru/search?tags=870
# /material/difficulty/5
# https://nplus1.ru/news/2024/04/18/goldene-synthesis
# /news/2024/04/03
# https://nplus1.ru/search?tags=880
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/03/very-big-camera-done
# /news/2024/04/03
# https://nplus1.ru/search?tags=869
# /material/difficulty/5
# https://nplus1.ru/news/2024/04/03/photons-to-tau
# /news/2024/04/04
# https://nplus1.ru/search?tags=883
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/04/delta-drone-monocycle
# /news/2024/04/12
# https://nplus1.ru/search?tags=883
# /material/difficulty/2
# https://nplus1.ru/news/2024/04/12/hopcopter
# /news/2024/03/28
# https://nplus1.ru/search?tags=877
# /material/difficulty/3
# https://nplus1.ru/news/2024/03/28/emperor-wu
# /blog/2024/04/17
# https://nplus1.ru/search?tags=869
# /material/difficulty/1
# https://nplus1.ru/blog/2024/04/17/helgoland
# /news/2024/04/05
# https://nplus1.ru/search?tags=872
# /material/difficulty/1
# https://nplus1.ru/news/2024/04/05/yellowstone-tourism-emissions
# https://nplus1.ru/blog/2024/04/03/exclusome
# /blog/2024/04/03
# https://nplus1.ru/search?tags=885
# https://nplus1.ru/search?tags=900
# /material/difficulty/7
# https://nplus1.ru/blog/2024/04/03/exclusome
# https://nplus1.ru/material/2024/02/22/put-cigarettes-out
# /material/2024/02/22
# https://nplus1.ru/search?tags=812
# /material/difficulty/3
# https://nplus1.ru/material/2024/02/22/put-cigarettes-out
# https://nplus1.ru/news/2024/04/02/mirror-image-cyclodextrins
# https://nplus1.ru/news/2024/04/02/asassn-20qc
# https://nplus1.ru/news/2024/04/03/photons-to-tau
# https://nplus1.ru/blog/2024/04/03/exclusome
# https://nplus1.ru/news/2024/04/05/gan-microring-single-photon-source
# https://nplus1.ru/news/2024/04/06/gw-bh-ns-or-no
# https://nplus1.ru/news/2024/04/10/neutrino-ignored-quantum-gravity
# https://nplus1.ru/news/2024/04/11/rotaxane-actuator
# https://nplus1.ru/news/2024/04/12/magnetic-and-mergers
# https://nplus1.ru/news/2024/04/15/bread-dark-photons
# https://nplus1.ru/news/2024/04/16/boat-sn
# https://nplus1.ru/news/2024/04/18/sympalamprey
# https://nplus1.ru/news/2024/04/18/ultrafast-kapitza-dirac
# https://nplus1.ru/news/2024/04/18/goldene-synthesis
# https://nplus1.ru/news/2024/04/18/jwst-w-1935
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# /cdn-cgi/l/email-protection#fe9092be908e928b8dcfd08c8b
# /cdn-cgi/l/email-protection#d0b9beb6bf90bea0bca5a3e1fea2a5
# /personal-data-policy
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin

# %% [markdown]
# Ссылок много. Но нам нужны только новости – ссылки, которые начинаются со слова `/news`. Добавим условие: будем выбирать только те ссылки, в которых есть `/news`. Создадим пустой список `urls` и будем добавлять в него только ссылки, которые удовлетворяют этому условию.

# %%
urls = []

for link in soup.find_all('a'):
#     print(link)
    if '/news' in link.get('href'):
        if 'https://' in link.get('href'):
            urls.append(link.get('href'))
urls
# Out:
# ['https://nplus1.ru/news/2024/04/17/orchid-bees',
#  'https://nplus1.ru/news/2024/04/22/dogs-vs-tapirs',
#  'https://nplus1.ru/news/2024/04/22/lead-mining',
#  'https://nplus1.ru/news/2024/04/22/ici-pregnancy',
#  'https://nplus1.ru/news/2024/04/22/beta-blockers-after-infarction',
#  'https://nplus1.ru/news/2024/04/20/deer-and-prions',
#  'https://nplus1.ru/news/2024/04/20/covid-613-days',
#  'https://nplus1.ru/news/2024/04/20/watch-yourself',
#  'https://nplus1.ru/news/2024/04/20/rotavirus-wins',
#  'https://nplus1.ru/news/2024/04/20/use-them',
#  'https://nplus1.ru/news/2024/04/19/vasuki-indicus',
#  'https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1',
#  'https://nplus1.ru/news/2024/04/19/pregnancy-outcomes-mortality',
#  'https://nplus1.ru/news/2024/04/19/para-to-meta-phenols',
#  'https://nplus1.ru/news/2024/04/19/mental-health-homelessness',
#  'https://nplus1.ru/news/2024/04/19/upwelling-killed-megafauna',
#  'https://nplus1.ru/news/2024/04/19/incised-bear-bone',
#  'https://nplus1.ru/news/2024/04/19/bombus-impatiens-flooding',
#  'https://nplus1.ru/news/2024/04/19/mandible-in-travertin-floor',
#  'https://nplus1.ru/news/2024/04/19/three-stelae',
#  'https://nplus1.ru/news/2024/04/19/no-more-airborne',
#  'https://nplus1.ru/news/2024/04/19/global-burden-all-diseases',
#  'https://nplus1.ru/news/2024/04/18/jwst-w-1935',
#  'https://nplus1.ru/news/2024/04/18/antipsychotic-use-adverse-outcomes',
#  'https://nplus1.ru/news/2024/04/18/hayabusa-2-off-mode',
#  'https://nplus1.ru/news/2024/04/18/goldene-synthesis',
#  'https://nplus1.ru/news/2024/04/18/dragonfly-go',
#  'https://nplus1.ru/news/2024/04/18/birds-babbling',
#  'https://nplus1.ru/news/2024/04/18/three-legged-chair-robot',
#  'https://nplus1.ru/news/2024/04/18/ingenuity-will-work-until-death',
#  'https://nplus1.ru/news/2024/04/18/ultrafast-kapitza-dirac',
#  'https://nplus1.ru/news/2024/04/18/maya-ucanal',
#  'https://nplus1.ru/news/2024/04/18/blue-tits-siring-success',
#  'https://nplus1.ru/news/2024/04/18/wisdom-coquetry',
#  'https://nplus1.ru/news/2024/04/18/narcosis-rules',
#  'https://nplus1.ru/news/2024/04/18/sympalamprey',
#  'https://nplus1.ru/news/2024/04/18/aortic-coarctation',
#  'https://nplus1.ru/news/2024/04/17/gymnogyps-californianus-egg',
#  'https://nplus1.ru/news/2024/04/09/cannibalism-in-hoopoes',
#  'https://nplus1.ru/news/2024/04/15/shipwreck-of-ses-fontanelles',
#  'https://nplus1.ru/news/2024/03/27/taste-of-beer',
#  'https://nplus1.ru/news/2024/04/18/wisdom-coquetry',
#  'https://nplus1.ru/news/2024/04/03/the-speed-of-sight',
#  'https://nplus1.ru/news/2024/04/12/zeolite-for-pe',
#  'https://nplus1.ru/news/2024/04/19/vasuki-indicus',
#  'https://nplus1.ru/news/2022/01/25/coronavirus-survivial',
#  'https://nplus1.ru/news/2024/03/27/javan-tiger',
#  'https://nplus1.ru/news/2024/04/02/asassn-20qc',
#  'https://nplus1.ru/news/2024/04/15/mummified-egyptian-head',
#  'https://nplus1.ru/news/2024/04/10/neutrino-ignored-quantum-gravity',
#  'https://nplus1.ru/news/2024/04/18/goldene-synthesis',
#  'https://nplus1.ru/news/2024/04/03/very-big-camera-done',
#  'https://nplus1.ru/news/2024/04/03/photons-to-tau',
#  'https://nplus1.ru/news/2024/04/04/delta-drone-monocycle',
#  'https://nplus1.ru/news/2024/04/12/hopcopter',
#  'https://nplus1.ru/news/2024/03/28/emperor-wu',
#  'https://nplus1.ru/news/2024/04/05/yellowstone-tourism-emissions',
#  'https://nplus1.ru/news/2024/04/02/mirror-image-cyclodextrins',
#  'https://nplus1.ru/news/2024/04/02/asassn-20qc',
#  'https://nplus1.ru/news/2024/04/03/photons-to-tau',
#  'https://nplus1.ru/news/2024/04/05/gan-microring-single-photon-source',
#  'https://nplus1.ru/news/2024/04/06/gw-bh-ns-or-no',
#  'https://nplus1.ru/news/2024/04/10/neutrino-ignored-quantum-gravity',
#  'https://nplus1.ru/news/2024/04/11/rotaxane-actuator',
#  'https://nplus1.ru/news/2024/04/12/magnetic-and-mergers',
#  'https://nplus1.ru/news/2024/04/15/bread-dark-photons',
#  'https://nplus1.ru/news/2024/04/16/boat-sn',
#  'https://nplus1.ru/news/2024/04/18/sympalamprey',
#  'https://nplus1.ru/news/2024/04/18/ultrafast-kapitza-dirac',
#  'https://nplus1.ru/news/2024/04/18/goldene-synthesis',
#  'https://nplus1.ru/news/2024/04/18/jwst-w-1935']

# %%
len(urls)
# Out:
# 71

# %%
urls[1]
# Out:
# 'https://nplus1.ru/news/2024/04/22/dogs-vs-tapirs'

# %% [markdown]
# Теперь наша задача сводится к следующему: изучить одну страницу с новостью, научиться из нее вытаскивать текст и всю необходимую информацию, а потом применить весь набор действий к каждой ссылке из `full_urls` в цикле. Посмотрим на новость с индексом 1, у вас может быть другая, новости обновляются.

# %%
url0 = urls[11]

page0 = requests.get(url0)
print(page0)

soup0 = BeautifulSoup(page0.text, 'html')
print(soup0)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Робот Limx Dynamics научился по-человечески ходить по лестнице. Компания рассказала о прогрессе в разработке человекоподобного робота</title>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
# <link href="/front-build/css/main.css?id=9b496fbb252428c03791da99722528ab" rel="stylesheet"/>
# <link href="/front-build/css/app.css?id=116ee51fc89adfd59429b373ba12b060" rel="stylesheet"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#f26e40" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1" rel="canonical"/>
# <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
# <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');</script>
# <!-- End Google Tag Manager -->
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="description"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
# <meta content="Робот Limx Dynamics научился по-человечески ходить по лестнице" property="og:title"/>
# <meta content="https://minio.nplus1.ru/app-images/909472/66226f00a7a2d_cover_share.jpg" property="og:image"/>
# <meta content="https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1" property="og:url"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="2024-04-19" itemprop="datePublished"/>
# <!-- amp page -->
# <link href="https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1/amp" rel="amphtml"/>
# <meta content="2024-04-19" itemprop="datePublished"/>
# <meta content="Андрей Фокин" name="mediator_author"/>
# <meta content="Андрей Фокин" name="author"/>
# <meta content="" name="copyright"/>
# <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "NewsArticle",
#       "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1"
#       },
#       "headline": "Робот Limx Dynamics научился по-человечески ходить по лестнице",
#       "description": "Компания рассказала о прогрессе в разработке человекоподобного робота",
#             "image": "https://minio.nplus1.ru/app-images/909472/66226f00a7a2d_cover_share.jpg",
#
#
#
#
#           "author": {
#         "@type": "Person",
#         "name": "Андрей Фокин",
#                 "image": "https://staticn1.nplus1.ru/image-new/logo-alt.png",
#               "url": "https://nplus1.ru/author/andrei-fokin"
#         },
#
#         "publisher": {
#       "@type": "Organization",
#       "name": "N+1",
#       "logo": {
#         "@type": "ImageObject",
#         "url": "https://minio.nplus1.ru/app-images/909472/66226f00a7a2d_cover_share.jpg"
#       }
#     },
#     "datePublished": "2024-04-19",
#       "dateModified": "2024-04-19"
#     }
#
#
#
#     </script>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@nplusodin" name="twitter:site"/>
# <meta content="Робот Limx Dynamics научился по-человечески ходить по лестнице" name="twitter:title"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
# <meta content="https://minio.nplus1.ru/app-images/909472/66226f00a7a2d_cover_share.jpg" name="twitter:image"/>
# <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# </head>
# <body class="antialiased">
# <!-- Top.Mail.Ru counter -->
# <script type="text/javascript">
#
# var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#
# </script>
# <noscript><div><img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/></div></noscript>
# <!-- /Top.Mail.Ru counter -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
# <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
# <div class="absolute bg-main-gray/5 bottom-0 left-0 top-0" id="progressBar" style="z-index: -1"></div>
# <div class="border-b border-main-gray h-full">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
# <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
# <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
# <svg class="w-full h-full">
# <use xlink:href="#n1_cross_menu"></use>
# </svg>
# </template>
# <template v-else="">
# <svg class="w-full h-full">
# <use xlink:href="#n1_burger"></use>
# </svg>
# </template>
# </button>
# <div>
# <a href="/">
# <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
# </a>
# </div>
# <a class="w-7.5 h-7.5" href="/search">
# <svg class="w-full h-full">
# <use xlink:href="#n1_pupa"></use>
# </svg>
# </a>
# </div>
# </div>
# <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
# <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>
# </div>
# <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
# <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка</a>
# </div>
# </div>
# <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка
#           </a>
# </div>
# <div class="max-w-full flex py-5 border-t border-gray-2">
# <div class="flex gap-x-5 overflow-x-auto">
# <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
# </div>
# </div>
# <div class="pt-5 pb-10 border-t border-gray-2 text-18">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <app-heading-nav></app-heading-nav>
# <section class="mb-15 md:mb-20">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-7.5 relative overflow-hidden" data-heading-wrap="">
# <!--tags-->
# <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 mt-5 -mb-2.5 lg:-mb-0 lg:mt-10 content-start mr-9">
# <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
# <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
# <span class="group-hover:text-main transition-colors duration-75">18:35</span>
# </span>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/news/2024/04/19">
# <span class="group-hover:text-main transition-colors duration-75">19.04.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">1.4</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=883">
# <span class="group-hover:text-main transition-colors duration-75">Роботы и дроны</span>
# </a>
# </div>
# <div class="hidden lg:flex items-center gap-x-2">
# <a class="group" href="https://nplus1.ru/material-print/68142" target="_blank">
# <svg class="group-hover:text-main transition-colors duration-75 stroke-current" fill="none" height="30" viewbox="0 0 22 30" width="22" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" width="21" x="0.5" y="0.5"></rect>
# <line x1="4" x2="18" y1="7.5" y2="7.5"></line>
# <line x1="4" x2="18" y1="21.5" y2="21.5"></line>
# <line x1="4" x2="18" y1="14.5" y2="14.5"></line>
# </svg>
# </a>
# <app-copy-material link="https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1" type="full-2"></app-copy-material>
# </div>
# <div class="w-full flex flex-col mt-5">
# </div>
# </div>
# <!--dotes menu mobile-->
# <template v-if="isMobile">
# <button class="absolute flex right-5 top-5 z-30 text-main-black">
# <svg class="fill-current" fill="none" height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 6C17 6.55228 16.5523 7 16 7H15C14.4477 7 14 6.55228 14 6V5C14 4.44772 14.4477 4 15 4H16C16.5523 4 17 4.44772 17 5V6ZM17 23C17 23.5523 16.5523 24 16 24H15C14.4477 24 14 23.5523 14 23V22C14 21.4477 14.4477 21 15 21H16C16.5523 21 17 21.4477 17 22V23ZM14 14.5C14 15.0523 14.4477 15.5 15 15.5H16C16.5523 15.5 17 15.0523 17 14.5V13.5C17 12.9477 16.5523 12.5 16 12.5H15C14.4477 12.5 14 12.9477 14 13.5V14.5Z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div :class="{
#            'transition-transform flex items-center gap-x-7.5 absolute top-0 right-0 w-full px-6 md:px-8 h-20 bg-white z-30 justify-end bg-light-gray':true,
#            '-translate-x-full': !isOpenMobileDotsMenu,
#            '-translate-x-0': isOpenMobileDotsMenu
#            }" ref="mobileDotsMenuRef">
# <app-copy-material link="https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1" type="mobile"></app-copy-material>
# <button aria-label="Go" class="group">
# <svg class="group-focus:text-main transition-colors duration-75 stroke-current" fill="none" height="40" viewbox="0 0 30 40" width="30" xmlns="http://www.w3.org/2000/svg">
# <path d="M14.3303 26.2967L0.5 38.8697V0.5H28.8333V38.8697L15.003 26.2967L14.6667 25.9909L14.3303 26.2967Z"></path>
# </svg>
# </button>
# <button aria-label="Go" class="group">
# <svg class="group-focus:text-main transition-colors duration-75 stroke-current" fill="none" height="40" viewbox="0 0 30 40" width="30" xmlns="http://www.w3.org/2000/svg">
# <rect height="39" width="28.3333" x="0.833984" y="0.5"></rect>
# <line x1="5.66732" x2="24.334" y1="10.1665" y2="10.1665"></line>
# <line x1="5.66732" x2="24.334" y1="28.8335" y2="28.8335"></line>
# <line x1="5.66732" x2="24.334" y1="19.5" y2="19.5"></line>
# </svg>
# </button>
# </div>
# </template>
# <!-- main image -->
# <!--main-->
# <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10">
# <div class="flex flex-col">
# <h1 class="text-34 md:text-42 xl:text-52 break-words">
#             Робот Limx Dynamics научился по-человечески ходить по лестнице
#           </h1>
# <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Компания рассказала о прогрессе в разработке человекоподобного робота</p>
# <div class="text-14 mb-5 sm:mb-12 flex flex-wrap">
# <span class="whitespace-nowrap">
# <a class="underline" href="/author/andrei-fokin">Андрей Фокин</a>
# </span>
# </div>
# <div class="mb-14" data-lmb-0="">
# <div class="n1_material text-18"><p class="mb-6">Робототехническая компания Limx Dynamics <a href="https://medium.com/@limxdynamics/limx-dynamics-elevates-humanoid-robotics-capabilities-with-updates-on-stair-climbing-and-running-621065209a3e" rel="noreferrer noopener" target="_blank">рассказала </a>о прогрессе в разработке человекоподобного робота CL-1. После улучшения алгоритмов восприятия и контроля над телом робот стал быстрее подниматься по лестницам — теперь он чередует ноги с каждым шагом, а не делает два шага на каждую ступеньку, как раньше. Одновременно с этим увеличилась скорость передвижения и улучшились динамические возможности робота. Это связано также с тем, что помимо программного обеспечения обновилась и аппаратная часть. В частности, возросла производительность актуаторов: повысился их крутящий момент и скорость работы. Кроме этого, конструкция робота стала более легкой и ударопрочной. Компания опубликовала <a href="https://www.youtube.com/watch?v=V98ru3ILkwo" rel="noreferrer noopener" target="_blank">видео</a> с испытаниями робота на YouTube.</p></div>
# <div class="block md:hidden col-span-6 mb-6">
# <div class="w-full" data-ref-sidebar=""></div>
# <a href="https://премиявызов.рф/?utm_source=nplus1&amp;utm_medium=banner&amp;utm_campaign=vyzovaward&amp;utm_content=news&amp;utm_term=vyzovaward" target="_blank">
# <picture>
# <source media="(min-width: 768px)" srcset="https://nplus1.ru/images-new/material-banner-3-desktop.jpg">
# <img alt="Вызов: национальная премия в области будущих технологий." class="w-full" loading="lazy" src="https://nplus1.ru/images-new/material-banner-3-mobile.jpg"/>
# </source></picture>
# </a>
# </div>
# <div class="n1_material text-18"><figure class="mb-6 embed-video"><div class="wp-block-embed__wrapper"><iframe allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen="" frameborder="0" referrerpolicy="strict-origin-when-cross-origin" src="https://www.youtube.com/embed/V98ru3ILkwo?feature=oembed" title="Humanoid, Keep Running! LimX Dynamics' Latest Updates on CL-1"></iframe></div></figure></div>
# <div class="n1_material text-18"><p class="mb-6">Помимо полноразмерного робота-гуманоида CL-1 в линейке роботов LimX Dynamics есть еще одна бипедальная модель. Небольшой робот P1 выглядит как платформа на двух ногах с выгнутыми в обратную сторону коленными суставами. Его основное предназначение — тестирование алгоритмов двуногой походки в разнообразных условиях. Недавно инженеры компании <a href="https://nplus1.ru/news/2024/03/20/llimx-p1-in-forest" rel="noreferrer noopener" target="_blank">отправили</a> робота на прогулку в дикую природу, чтобы испытать его в условиях сильно пересеченного естественного ландшафта.</p></div>
# </div>
# <div class="text-18">
# <div class="text-20 font-spectral text-main-gray leading-none" v-if="!isMobile">
#               Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.
#             </div>
# </div>
# </div>
# </div>
# <!--right sidebar-->
# <div class="block col-span-6 md:col-span-4 lg:col-span-3 mt-10">
# <div class="w-full" data-ref-sidebar=""></div>
# <a class="hidden md:block" href="https://премиявызов.рф/?utm_source=nplus1&amp;utm_medium=banner&amp;utm_campaign=vyzovaward&amp;utm_content=news&amp;utm_term=vyzovaward" target="_blank">
# <picture>
# <source media="(min-width: 768px)" srcset="https://nplus1.ru/images-new/material-banner-3-desktop.jpg">
# <img alt="Вызов: национальная премия в области будущих технологий." class="w-full" loading="lazy" src="https://nplus1.ru/images-new/material-banner-3-mobile.jpg"/>
# </source></picture>
# </a>
# <!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div class="bg-gray-100 mt-2 py-4 w-full" id="adfox_153934342663011746"></div>
# <!--
#         <a class="text-14 leading-21 group" href="#">
#           <p>
#             Human mobility at Tell Atchana (Alalakh), Hatay, Turkey during the 2nd millennium BC: Integration of
#             isotopic and genomic evidence
#           </p>
#           <div class="group-hover:text-main inline-flex items-center font-spectral text-main-gray">
#             <p class="mr-1">PLOS ONE, 30.06.2021</p>
#             <svg class="fill-current" width="11" height="11" viewBox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#               <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z"
#                     fill="currentColor"></path>
#             </svg>
#           </div>
#         </a>
#         -->
# </div>
# </div>
# </section>
# <section class="mb-15 md:mb-20">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--tags-->
# <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 -mb-2.5 lg:-mb-0 content-start">
# <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
# <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
# <span class="group-hover:text-main transition-colors duration-75">08:10</span>
# </span>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/news/2024/03/31">
# <span class="group-hover:text-main transition-colors duration-75">31.03.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">1.7</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=883">
# <span class="group-hover:text-main transition-colors duration-75">Роботы и дроны</span>
# </a>
# </div>
# <div class="hidden lg:flex items-center gap-x-2">
# <a aria-label="Go" class="group" href="https://nplus1.ru/material-print/67990">
# <svg class="group-hover:text-main transition-colors duration-75 stroke-current" fill="none" height="30" viewbox="0 0 22 30" width="22" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" width="21" x="0.5" y="0.5"></rect>
# <line x1="4" x2="18" y1="7.5" y2="7.5"></line>
# <line x1="4" x2="18" y1="21.5" y2="21.5"></line>
# <line x1="4" x2="18" y1="14.5" y2="14.5"></line>
# </svg>
# </a>
# <app-copy-material link="https://nplus1.ru/news/2024/03/31/crawfish" type="full-2"></app-copy-material>
# </div>
# </div>
# <!--main image  -->
# <!--main-->
# <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10 lg:mt-0">
# <div class="flex flex-col">
# <div class="text-34 md:text-42 xl:text-52 break-words">
#           Подводный робот на колесах обработает подводные сооружения антикоррозионным составом
#         </div>
# <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">И поищет трещины в сварных швах</p>
# <div class="text-14 pt-4 sm:pt-6 mb-10 sm:mb-12 flex flex-wrap">
# <a class="underline whitespace-nowrap" href="/author/andrei-fokin">Андрей Фокин</a>
# </div>
# <div class="n1_material text-18" id="read-next-2">
# <p class="mb-6">Инженеры из Общества Фраунгофера разработали подводный робот Crawfish для технического обслуживания подводной части морских сооружений, таких, например, как ветрогенераторы, нефтяные платформы, волновые и приливные электростанции. Робот имеет гибридную конструкцию, состоящую из подводного дрона и модуля с колесами, а также набор полезных инструментов. Его можно использовать для дистанционного поиска повреждений, трещин в сварных швах, а также для нанесения антикоррозионного покрытия, сообщает New Atlas.</p>
# </div>
# <div class="mt-5 md:mt-6">
# <a class="inline-flex justify-center bg-main w-full py-4" href="https://nplus1.ru/news/2024/03/31/crawfish">
# <span class="text-white text-22 md:text-24">Читать дальше</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-15 md:mb-20">
# <div class="bg-gray-100 w-full" id="adfox_154408219501673625"></div>
# </section>
# <div class="mb-1 w-full overflow-hidden">
# <app-material-slider-carousel :const-container="constContainer" :const-start-container="constStartContainer">
# <template v-slot:default="slotProps">
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                                'padding-left': slotProps.left + 'px'
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/906138/conversions/8eb46937ae181723816a77c6e77ce9be-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/906137/conversions/b9fc2d4894cf94bd753d0a41d77a7d97-conversion-webp.webp">
# <img alt="Младшие птенцы удодов оказались консервами для выкармливания старших" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/906137/conversions/b9fc2d4894cf94bd753d0a41d77a7d97-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/04/09">
# <span class="group-hover:text-main transition-colors duration-75">09.04.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=874">
# <span class="group-hover:text-main transition-colors duration-75">
#             Зоология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           4.5
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus-1.ru/news/2024/04/09/cannibalism-in-hoopoes">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Младшие птенцы удодов оказались консервами для выкармливания старших</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Самки удодов откладывают избыточное количество яиц, а затем кормят старших птенцов младшими</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/907635/conversions/661a4fe473e38_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/907636/conversions/661a4fe4bb2a6_hl_cover_h-conversion-webp.webp">
# <img alt="В амфорах с затонувшего античного корабля нашли остатки гарума из анчоусов" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/907636/conversions/661a4fe4bb2a6_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/04/15">
# <span class="group-hover:text-main transition-colors duration-75">15.04.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=876">
# <span class="group-hover:text-main transition-colors duration-75">
#             Археология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           2.5
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus-1.ru/news/2024/04/15/shipwreck-of-ses-fontanelles">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           В амфорах с затонувшего античного корабля нашли остатки гарума из анчоусов</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Остов этого судна обнаружили у берегов Мальорки</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/901869/conversions/660408f22ddf0_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/901870/conversions/660408f2c3389_hl_cover_h-conversion-webp.webp">
# <img alt="Этилацетат оказался самым важным компонентом бельгийского пива" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/901870/conversions/660408f2c3389_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/03/27">
# <span class="group-hover:text-main transition-colors duration-75">27.03.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=870">
# <span class="group-hover:text-main transition-colors duration-75">
#             Химия
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           4.1
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus-1.ru/news/2024/03/27/taste-of-beer">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Этилацетат оказался самым важным компонентом бельгийского пива</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             А этанол оказался не таким уж и нужным</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/908695/conversions/66207668b6b71_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/908696/conversions/662076690b22a_hl_cover_h-conversion-webp.webp">
# <img alt="Самая старая дикая птица не дождалась постоянного партнера и пофлиртовала с несколькими самцами" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/908696/conversions/662076690b22a_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/04/18">
# <span class="group-hover:text-main transition-colors duration-75">18.04.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=874">
# <span class="group-hover:text-main transition-colors duration-75">
#             Зоология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           1.2
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus-1.ru/news/2024/04/18/wisdom-coquetry">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Самая старая дикая птица не дождалась постоянного партнера и пофлиртовала с несколькими самцами</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             72-летняя самка альбатроса не приносит потомства уже третий год подряд</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/904430/conversions/660d0d303cf86_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/904431/conversions/660d0d307ff85_hl_cover_h-conversion-webp.webp">
# <img alt="Свет начал мерцать для разных людей на разной частоте" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/904431/conversions/660d0d307ff85_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/04/03">
# <span class="group-hover:text-main transition-colors duration-75">03.04.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=885">
# <span class="group-hover:text-main transition-colors duration-75">
#             Биология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           2.1
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus-1.ru/news/2024/04/03/the-speed-of-sight">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Свет начал мерцать для разных людей на разной частоте</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Ученые обнаружили разницу в скорости зрительного восприятия</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/907363/conversions/dfd7675edabff0e8ed783d93ca3efd7e-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/907362/conversions/2515337ae126153b4eae43be2d097acb-conversion-webp.webp">
# <img alt="Цеолит помог превратить полиэтилен в бензин" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/907362/conversions/2515337ae126153b4eae43be2d097acb-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/04/12">
# <span class="group-hover:text-main transition-colors duration-75">12.04.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=870">
# <span class="group-hover:text-main transition-colors duration-75">
#             Химия
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           3.4
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus-1.ru/news/2024/04/12/zeolite-for-pe">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Цеолит помог превратить полиэтилен в бензин</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Выход продукта составил 81 процент</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/909353/conversions/6622381f5cf2c_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/909354/conversions/6622381faef68_hl_cover_h-conversion-webp.webp">
# <img alt="Индийские палеонтологи описали потенциально крупнейшую змею в истории. Она достигала 1115 метров в длину" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/909354/conversions/6622381faef68_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/04/19">
# <span class="group-hover:text-main transition-colors duration-75">19.04.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=878">
# <span class="group-hover:text-main transition-colors duration-75">
#             Палеонтология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           4.1
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus-1.ru/news/2024/04/19/vasuki-indicus">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Индийские палеонтологи описали потенциально крупнейшую змею в истории. Она достигала 1115 метров в длину</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Впрочем, авторы предупреждают, что пока данных недостаточно для точных оценок</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/240931/conversions/630199238e8a1_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/240932/conversions/63019923b6e23_hl_cover_h-conversion-webp.webp">
# ...
# <ul class="flex gap-3 text-gray-2">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M11 5V17"></path>
# <path d="M6.75781 6.75781L15.2431 15.2431"></path>
# <path d="M17 11L5 11"></path>
# <path d="M15.2422 6.75781L6.75691 15.2431"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle cx="25" cy="25" r="24.5"></circle>
# <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10"></path>
# </svg>
# <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
# <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625"></animate>
# </path>
# </svg>
# <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
# <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"></path>
# <path d="M13 1L1 13" stroke="#F9F9F9"></path>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd"></path>
# <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5"></rect>
# <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"></path>
# </svg>
# <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <mask id="path-1-inside-1_2694_77554">
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd"></path>
# </mask>
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd"></path>
# <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)"></path>
# </svg>
# <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# <path class="stroke-current" d="M18 35V15L36 25L18 35Z"></path>
# </svg>
# <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd"></path>
# </svg>
# <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <line stroke="#32363A" x2="30" y1="6.5" y2="6.5"></line>
# <line stroke="#32363A" x2="30" y1="23.5" y2="23.5"></line>
# <line stroke="#32363A" x2="30" y1="15" y2="15"></line>
# </svg>
# <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <path d="M4 4L26 26" stroke="#32363A"></path>
# <path d="M26 4L4 26" stroke="#32363A"></path>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
# <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"></path>
# </svg>
# <svg id="n1_specials_star" style="display:block;width:0;height:0;fill:none;stroke:white" version="1.1" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
# <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round"></path>
# </svg>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/front-build/js/app.js?id=44d98c282e99e6db71221ad7537063dd"></script>
# <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
# <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
# </body>
# </html>

# %% [markdown]
# В коде каждой страницы с новостью есть часть с мета-информацией: датой, именем автора и проч. Такая информация окружена тэгом `<meta></meta>`. Посмотрим:

# %%
soup0.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>,
#  <meta content="#f26e40" name="msapplication-TileColor"/>,
#  <meta content="#ffffff" name="theme-color"/>,
#  <meta content="8c90b02c84ac3b72" name="yandex-verification"/>,
#  <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" name="description"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>,
#  <meta content="Добытый в Польше свинец экспортировали в Древнюю Русь" property="og:title"/>,
#  <meta content="https://minio.nplus1.ru/app-images/909738/66262702eb30e_cover_share.jpeg" property="og:image"/>,
#  <meta content="https://nplus1.ru/news/2024/04/22/lead-mining" property="og:url"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>,
#  <meta content="article" property="og:type"/>,
#  <meta content="2024-04-22" itemprop="datePublished"/>,
#  <meta content="2024-04-22" itemprop="datePublished"/>,
#  <meta content="Михаил Подрезов" name="mediator_author"/>,
#  <meta content="Михаил Подрезов" name="author"/>,
#  <meta content="" name="copyright"/>,
#  <meta content="summary_large_image" name="twitter:card"/>,
#  <meta content="@nplusodin" name="twitter:site"/>,
#  <meta content="Добытый в Польше свинец экспортировали в Древнюю Русь" name="twitter:title"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>,
#  <meta content="https://minio.nplus1.ru/app-images/909738/66262702eb30e_cover_share.jpeg" name="twitter:image"/>]

# %%
soup0.find('meta', {'property': 'og:title'}).get('content')
# Out:
# 'Робот Limx Dynamics научился по-человечески ходить по\xa0лестнице'

# %%
soup0.find_all('meta', {'itemprop': 'datePublished'})[0].get('content')
# Out:
# '2024-04-22'

# %% [markdown]
# Из этого списка нам нужны части с именем автора, датой, заголовком и кратким описанием. Воспользуемся поиском по атрибуту `name`. Передадим функции `find_all()` в качестве аргумента словарь с названием и значением атрибута:

# %%
soup0.find_all('meta', {'name' : 'author'}) # например, автор
# Out:
# [<meta content="Михаил Подрезов" name="author"/>]

# %% [markdown]
# Теперь выберем единственный элемент полученного списка (с индексом 0):

# %%
soup0.find_all('meta', {'name' : 'author'})[0]
# Out:
# <meta content="Михаил Подрезов" name="author"/>

# %% [markdown]
# Нам нужно вытащить из этого объекта `content` – имя автора. Посмотрим на атрибуты:

# %%
soup0.find_all('meta', {'name' : 'author'})[0].attrs
# Out:
# {'name': 'author', 'content': 'Михаил Подрезов'}

# %% [markdown]
# Как получить отсюда `content`? Очень просто, ведь это словарь! А доставать из словаря значение по ключу мы умеем.

# %%
author = soup0.find('meta', {'name' : 'author'}).get('content')
author
# Out:
# 'Михаил Подрезов'

# %% [markdown]
# Аналогичным образом извлечем дату, заголовок и описание.

# %%
date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].get('content')
title = soup0.find_all('meta', {'property' : 'og:title'})[0].get('content')

# %%
title
# Out:
# 'Добытый в\xa0Польше свинец экспортировали в\xa0Древнюю Русь'

# %%
date
# Out:
# '2024-04-22'

# %% [markdown]
# Теперь осталось совсем чуть-чуть. Написать готовую функцию для всех проделанных нами действий и применить ее в цикле для всех ссылок в списке `full_urls`. Напишем! Аргументом функции будет ссылка на новость, а возвращать она будет текст новости и всю необходимую информацию (дата, автор, сложность и проч.). Скопируем все строки кода выше.

# %%
def GetNews(url0):
    """
    Возвращает кортеж с url0, date, author, title.
    Параметры:
    
    url0 - ссылка на новость (строка).
    """
    page0 = requests.get(url0)
    soup0 = BeautifulSoup(page0.text, 'html')
    
    author = soup0.find_all('meta', {'name' : 'author'})[0].get('content')
    date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].get('content')
    title = soup0.find_all('meta', {'property' : 'og:title'})[0].get('content')
     
    return url0, date, author, title

# %%
help(GetNews)
# Out:
# Help on function GetNews in module __main__:
#
# GetNews(url0)
#     Возвращает кортеж с url0, date, author, title.
#     Параметры:
#
#     url0 - ссылка на новость (строка).

# %% [markdown]
# Уфф. Осталось применить ее в цикле. Но давайте не будем спешить: импортируем функцию `sleep` для задержки, чтобы на каждой итерации цикла, прежде чем перейти к следующей новости, Python ждал несколько секунд. Во-первых, это нужно, чтобы сайт «не понял», чтобы мы его грабим, да еще автоматически. Во-вторых, с небольшой задержкой всегда есть гарантия, что страница прогрузится (сейчас это пока не очень важно, но особенно актуально будет, когда будем обсуждать встраивание в браузер с Selenium). Приступим.

# %%
from time import sleep

# %%
urls
# Out:
# ['https://nplus1.ru/news/2024/04/17/orchid-bees',
#  'https://nplus1.ru/news/2024/04/22/dogs-vs-tapirs',
#  'https://nplus1.ru/news/2024/04/22/lead-mining',
#  'https://nplus1.ru/news/2024/04/22/ici-pregnancy',
#  'https://nplus1.ru/news/2024/04/22/beta-blockers-after-infarction',
#  'https://nplus1.ru/news/2024/04/20/deer-and-prions',
#  'https://nplus1.ru/news/2024/04/20/covid-613-days',
#  'https://nplus1.ru/news/2024/04/20/watch-yourself',
#  'https://nplus1.ru/news/2024/04/20/rotavirus-wins',
#  'https://nplus1.ru/news/2024/04/20/use-them',
#  'https://nplus1.ru/news/2024/04/19/vasuki-indicus',
#  'https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1',
#  'https://nplus1.ru/news/2024/04/19/pregnancy-outcomes-mortality',
#  'https://nplus1.ru/news/2024/04/19/para-to-meta-phenols',
#  'https://nplus1.ru/news/2024/04/19/mental-health-homelessness',
#  'https://nplus1.ru/news/2024/04/19/upwelling-killed-megafauna',
#  'https://nplus1.ru/news/2024/04/19/incised-bear-bone',
#  'https://nplus1.ru/news/2024/04/19/bombus-impatiens-flooding',
#  'https://nplus1.ru/news/2024/04/19/mandible-in-travertin-floor',
#  'https://nplus1.ru/news/2024/04/19/three-stelae',
#  'https://nplus1.ru/news/2024/04/19/no-more-airborne',
#  'https://nplus1.ru/news/2024/04/19/global-burden-all-diseases',
#  'https://nplus1.ru/news/2024/04/18/jwst-w-1935',
#  'https://nplus1.ru/news/2024/04/18/antipsychotic-use-adverse-outcomes',
#  'https://nplus1.ru/news/2024/04/18/hayabusa-2-off-mode',
#  'https://nplus1.ru/news/2024/04/18/goldene-synthesis',
#  'https://nplus1.ru/news/2024/04/18/dragonfly-go',
#  'https://nplus1.ru/news/2024/04/18/birds-babbling',
#  'https://nplus1.ru/news/2024/04/18/three-legged-chair-robot',
#  'https://nplus1.ru/news/2024/04/18/ingenuity-will-work-until-death',
#  'https://nplus1.ru/news/2024/04/18/ultrafast-kapitza-dirac',
#  'https://nplus1.ru/news/2024/04/18/maya-ucanal',
#  'https://nplus1.ru/news/2024/04/18/blue-tits-siring-success',
#  'https://nplus1.ru/news/2024/04/18/wisdom-coquetry',
#  'https://nplus1.ru/news/2024/04/18/narcosis-rules',
#  'https://nplus1.ru/news/2024/04/18/sympalamprey',
#  'https://nplus1.ru/news/2024/04/18/aortic-coarctation',
#  'https://nplus1.ru/news/2024/04/17/gymnogyps-californianus-egg',
#  'https://nplus1.ru/news/2024/04/09/cannibalism-in-hoopoes',
#  'https://nplus1.ru/news/2024/04/15/shipwreck-of-ses-fontanelles',
#  'https://nplus1.ru/news/2024/03/27/taste-of-beer',
#  'https://nplus1.ru/news/2024/04/18/wisdom-coquetry',
#  'https://nplus1.ru/news/2024/04/03/the-speed-of-sight',
#  'https://nplus1.ru/news/2024/04/12/zeolite-for-pe',
#  'https://nplus1.ru/news/2024/04/19/vasuki-indicus',
#  'https://nplus1.ru/news/2022/01/25/coronavirus-survivial',
#  'https://nplus1.ru/news/2024/03/27/javan-tiger',
#  'https://nplus1.ru/news/2024/04/02/asassn-20qc',
#  'https://nplus1.ru/news/2024/04/15/mummified-egyptian-head',
#  'https://nplus1.ru/news/2024/04/10/neutrino-ignored-quantum-gravity',
#  'https://nplus1.ru/news/2024/04/18/goldene-synthesis',
#  'https://nplus1.ru/news/2024/04/03/very-big-camera-done',
#  'https://nplus1.ru/news/2024/04/03/photons-to-tau',
#  'https://nplus1.ru/news/2024/04/04/delta-drone-monocycle',
#  'https://nplus1.ru/news/2024/04/12/hopcopter',
#  'https://nplus1.ru/news/2024/03/28/emperor-wu',
#  'https://nplus1.ru/news/2024/04/05/yellowstone-tourism-emissions',
#  'https://nplus1.ru/news/2024/04/02/mirror-image-cyclodextrins',
#  'https://nplus1.ru/news/2024/04/02/asassn-20qc',
#  'https://nplus1.ru/news/2024/04/03/photons-to-tau',
#  'https://nplus1.ru/news/2024/04/05/gan-microring-single-photon-source',
#  'https://nplus1.ru/news/2024/04/06/gw-bh-ns-or-no',
#  'https://nplus1.ru/news/2024/04/10/neutrino-ignored-quantum-gravity',
#  'https://nplus1.ru/news/2024/04/11/rotaxane-actuator',
#  'https://nplus1.ru/news/2024/04/12/magnetic-and-mergers',
#  'https://nplus1.ru/news/2024/04/15/bread-dark-photons',
#  'https://nplus1.ru/news/2024/04/16/boat-sn',
#  'https://nplus1.ru/news/2024/04/18/sympalamprey',
#  'https://nplus1.ru/news/2024/04/18/ultrafast-kapitza-dirac',
#  'https://nplus1.ru/news/2024/04/18/goldene-synthesis',
#  'https://nplus1.ru/news/2024/04/18/jwst-w-1935']

# %%
from tqdm import tqdm

# %%
news = [] # это будет список из кортежей, в которых будут храниться данные по каждой новости

for link in tqdm(urls[1:]):
    res = GetNews(link)
    news.append(res)
        
    sleep(3) # задержка в 3 секунды
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 70/70 [04:18<00:00,  3.70s/it]

# %%
news
# Out:
# [('https://nplus1.ru/news/2024/04/22/lead-mining',
#   '2024-04-22',
#   'Михаил Подрезов',
#   'Добытый в\xa0Польше свинец экспортировали в\xa0Древнюю Русь'),
#  ('https://nplus1.ru/news/2024/04/22/ici-pregnancy',
#   '2024-04-22',
#   'Слава Гоменюк',
#   'Ингибиторы контрольных точек иммунитета не\xa0повысили риск патологий беременности'),
#  ('https://nplus1.ru/news/2024/04/22/beta-blockers-after-infarction',
#   '2024-04-22',
#   'Слава Гоменюк',
#   'Бета-блокаторы не\xa0снизили риск смерти у\xa0пациентов с\xa0инфарктом миокарда'),
#  ('https://nplus1.ru/news/2024/04/20/deer-and-prions',
#   '2024-04-20',
#   'Сергей Коленов',
#   'Двух американских охотников назвали первыми возможными жертвами прионной болезни оленей среди людей'),
#  ('https://nplus1.ru/news/2024/04/20/covid-613-days',
#   '2024-04-20',
#   'Слава Гоменюк',
#   'Ученые обнаружили новый штамм коронавируса у\xa0пациента с\xa0613-дневным ковидом'),
#  ('https://nplus1.ru/news/2024/04/20/watch-yourself',
#   '2024-04-20',
#   'Олег Лищук',
#   'Вероятность алкогольных блэкаутов связали со\xa0скоростью и\xa0продолжительностью интоксикации'),
#  ('https://nplus1.ru/news/2024/04/20/rotavirus-wins',
#   '2024-04-20',
#   'Слава Гоменюк',
#   'Ротавирус оказался наиболее распространенным возбудителем смертельной диареи у\xa0детей'),
#  ('https://nplus1.ru/news/2024/04/20/use-them',
#   '2024-04-20',
#   'Олег Лищук',
#   'Американские врачи пренебрегли новыми антибиотиками при лечении устойчивых инфекций'),
#  ('https://nplus1.ru/news/2024/04/19/vasuki-indicus',
#   '2024-04-19',
#   'Сергей Коленов',
#   'Индийские палеонтологи описали потенциально крупнейшую змею в\xa0истории. Она достигала 11&#150;15 метров в\xa0длину'),
#  ('https://nplus1.ru/news/2024/04/19/limx-dynamics-cl1-update-1',
#   '2024-04-19',
#   'Андрей Фокин',
#   'Робот Limx Dynamics научился по-человечески ходить по\xa0лестнице'),
#  ('https://nplus1.ru/news/2024/04/19/pregnancy-outcomes-mortality',
#   '2024-04-19',
#   'Слава Гоменюк',
#   'Осложнения беременности повысили риск смерти от\xa0всех причин'),
#  ('https://nplus1.ru/news/2024/04/19/para-to-meta-phenols',
#   '2024-04-19',
#   'Михаил Бойм',
#   'Фенолы изомеризовались в\xa0три стадии'),
#  ('https://nplus1.ru/news/2024/04/19/mental-health-homelessness',
#   '2024-04-19',
#   'Слава Гоменюк',
#   'Две трети бездомных пострадали от\xa0ментальных расстройств'),
#  ('https://nplus1.ru/news/2024/04/19/upwelling-killed-megafauna',
#   '2024-04-19',
#   'Марина Попова',
#   'Усиление прибрежных апвеллингов назвали угрозой для мигрирующих морских обитателей'),
#  ('https://nplus1.ru/news/2024/04/19/incised-bear-bone',
#   '2024-04-19',
#   'Михаил Подрезов',
#   'Медвежью кость с\xa0насечками назвали символическим предметом неандертальцев'),
#  ('https://nplus1.ru/news/2024/04/19/bombus-impatiens-flooding',
#   '2024-04-19',
#   'Сергей Коленов',
#   'Энтомологи случайно затопили зимующих шмелей и\xa0обнаружили у\xa0них способность неделю выживать под водой'),
#  ('https://nplus1.ru/news/2024/04/19/mandible-in-travertin-floor',
#   '2024-04-19',
#   'Михаил Подрезов',
#   'Пользователь Reddit заметил челюсть древнего гоминина в\xa0травертиновой плитке'),
#  ('https://nplus1.ru/news/2024/04/19/three-stelae',
#   '2024-04-19',
#   'Михаил Подрезов',
#   'Археологи описали три каменные стелы из\xa0скифской «Долины царей»'),
#  ('https://nplus1.ru/news/2024/04/19/no-more-airborne',
#   '2024-04-19',
#   'Олег Лищук',
#   'Ковид заставил ВОЗ переименовать воздушно-капельный путь передачи инфекций'),
#  ('https://nplus1.ru/news/2024/04/19/global-burden-all-diseases',
#   '2024-04-19',
#   'Слава Гоменюк',
#   'Пандемия ковида значительно затормозила снижение глобального числа нетрудоспособных лет жизни'),
#  ('https://nplus1.ru/news/2024/04/18/jwst-w-1935',
#   '2024-04-18',
#   'Александр Войтюк',
#   '«Джеймс Уэбб» заметил нагрев стратосферы холодного коричневого карлика полярными сияниями'),
#  ('https://nplus1.ru/news/2024/04/18/antipsychotic-use-adverse-outcomes',
#   '2024-04-18',
#   'Слава Гоменюк',
#   'Антипсихотики повысили риск переломов и\xa0пневмонии у\xa0людей с\xa0деменцией'),
#  ('https://nplus1.ru/news/2024/04/18/hayabusa-2-off-mode',
#   '2024-04-18',
#   'Александр Войтюк',
#   '«Хаябуса-2» потеряет связь с\xa0Землей на\xa0три месяца'),
#  ('https://nplus1.ru/news/2024/04/18/goldene-synthesis',
#   '2024-04-18',
#   'Михаил Бойм',
#   'Химики синтезировали голден'),
#  ('https://nplus1.ru/news/2024/04/18/dragonfly-go',
#   '2024-04-18',
#   'Александр Войтюк',
#   'NASA одобрило постройку октокоптера для Титана'),
#  ('https://nplus1.ru/news/2024/04/18/birds-babbling',
#   '2024-04-18',
#   'Катерина Петрова',
#   'Лепет помог птенцам зебровых амадин запомнить отцовскую песню'),
#  ('https://nplus1.ru/news/2024/04/18/three-legged-chair-robot',
#   '2024-04-18',
#   'Андрей Фокин',
#   'Японцы сделали робоверсию ожившего трехногого стула из\xa0аниме'),
#  ('https://nplus1.ru/news/2024/04/18/ingenuity-will-work-until-death',
#   '2024-04-18',
#   'Александр Войтюк',
#   '«Индженьюити» превратили в\xa0автономный метеорологический пост'),
#  ('https://nplus1.ru/news/2024/04/18/ultrafast-kapitza-dirac',
#   '2024-04-18',
#   'Дмитрий Рудик',
#   'Физики увидели сверхбыстрый эффект Капицы\xa0— Дирака'),
#  ('https://nplus1.ru/news/2024/04/18/maya-ucanal',
#   '2024-04-18',
#   'Винера Андреева',
#   'Смену власти в\xa0майяском городе отметили сожжением останков прежних правителей'),
#  ('https://nplus1.ru/news/2024/04/18/blue-tits-siring-success',
#   '2024-04-18',
#   'Катерина Петрова',
#   'Молодые самцы лазоревок уступили чужих самок старшим сородичам'),
#  ('https://nplus1.ru/news/2024/04/18/wisdom-coquetry',
#   '2024-04-18',
#   'Сергей Коленов',
#   'Самая старая дикая птица не\xa0дождалась постоянного партнера и\xa0пофлиртовала с\xa0несколькими самцами'),
#  ('https://nplus1.ru/news/2024/04/18/narcosis-rules',
#   '2024-04-18',
#   'Олег Лищук',
#   'Общая анестезия при колоноскопии повысила выявляемость зубчатых полипов'),
#  ('https://nplus1.ru/news/2024/04/18/sympalamprey',
#   '2024-04-18',
#   'Олег Лищук',
#   'У\xa0миног нашли зачатки симпатической нервной системы'),
#  ('https://nplus1.ru/news/2024/04/18/aortic-coarctation',
#   '2024-04-18',
#   'Слава Гоменюк',
#   'Китаец прожил 35\xa0лет с\xa0просветом аорты в\xa0три миллиметра'),
#  ('https://nplus1.ru/news/2024/04/17/gymnogyps-californianus-egg',
#   '2024-04-17',
#   'Сергей Коленов',
#   'Ветеринары показали томограмму яйца калифорнийского кондора'),
#  ('https://nplus1.ru/news/2024/04/17/atlas-is-electric-now',
#   '2024-04-17',
#   'Андрей Фокин',
#   'Гидравлический Atlas уступил место электрическому'),
#  ('https://nplus1.ru/news/2024/04/09/cannibalism-in-hoopoes',
#   '2024-04-09',
#   'Сергей Коленов',
#   'Младшие птенцы удодов оказались консервами для выкармливания старших'),
#  ('https://nplus1.ru/news/2024/04/15/shipwreck-of-ses-fontanelles',
#   '2024-04-15',
#   'Михаил Подрезов',
#   'В\xa0амфорах с\xa0затонувшего античного корабля нашли остатки гарума из\xa0анчоусов'),
#  ('https://nplus1.ru/news/2024/03/27/taste-of-beer',
#   '2024-03-27',
#   'Артем Моськин',
#   'Этилацетат оказался самым важным компонентом бельгийского пива'),
#  ('https://nplus1.ru/news/2024/04/18/wisdom-coquetry',
#   '2024-04-18',
#   'Сергей Коленов',
#   'Самая старая дикая птица не\xa0дождалась постоянного партнера и\xa0пофлиртовала с\xa0несколькими самцами'),
#  ('https://nplus1.ru/news/2024/04/03/the-speed-of-sight',
#   '2024-04-03',
#   'Катерина Петрова',
#   'Свет начал мерцать для разных людей на\xa0разной частоте'),
#  ('https://nplus1.ru/news/2024/04/12/zeolite-for-pe',
#   '2024-04-12',
#   'Михаил Бойм',
#   'Цеолит помог превратить полиэтилен в\xa0бензин'),
#  ('https://nplus1.ru/news/2024/04/19/vasuki-indicus',
#   '2024-04-19',
#   'Сергей Коленов',
#   'Индийские палеонтологи описали потенциально крупнейшую змею в\xa0истории. Она достигала 11&#150;15 метров в\xa0длину'),
#  ('https://nplus1.ru/news/2022/01/25/coronavirus-survivial',
#   '2022-01-25',
#   'Анастасия Кузнецова–Фантони',
#   'Омикрон оказался самым устойчивым во внешней среде вариантом коронавируса'),
#  ('https://nplus1.ru/news/2024/03/27/javan-tiger',
#   '2024-03-27',
#   'Сергей Коленов',
#   'Найденный на\xa0изгороди волос заставил зоологов усомниться в\xa0вымирании яванских тигров'),
#  ('https://nplus1.ru/news/2024/04/02/asassn-20qc',
#   '2024-04-02',
#   'Александр Войтюк',
#   'Черная дыра промежуточной массы выдала себя пролетами сквозь аккреционный поток вблизи сверхмассивной черной дыры'),
#  ('https://nplus1.ru/news/2024/04/15/mummified-egyptian-head',
#   '2024-04-15',
#   'Михаил Подрезов',
#   'Антропологи подтвердили подлинность головы египетской мумии из\xa0итальянского музея'),
#  ('https://nplus1.ru/news/2024/04/10/neutrino-ignored-quantum-gravity',
#   '2024-04-10',
#   'Дмитрий Рудик',
#   'На\xa0нейтрино не\xa0подействовала квантовая гравитация'),
#  ('https://nplus1.ru/news/2024/04/18/goldene-synthesis',
#   '2024-04-18',
#   'Михаил Бойм',
#   'Химики синтезировали голден'),
#  ('https://nplus1.ru/news/2024/04/03/very-big-camera-done',
#   '2024-04-03',
#   'Александр Войтюк',
#   'Построена крупнейшая цифровая камера в\xa0истории'),
#  ('https://nplus1.ru/news/2024/04/03/photons-to-tau',
#   '2024-04-03',
#   'Дмитрий Рудик',
#   'Два фотона превратились в\xa0два тау-лептона в\xa0протон-протонных столкновениях'),
#  ('https://nplus1.ru/news/2024/04/04/delta-drone-monocycle',
#   '2024-04-04',
#   'Андрей Фокин',
#   'Многозвенный дрон-колесо прокатился на\xa0тяге пропеллеров'),
#  ('https://nplus1.ru/news/2024/04/12/hopcopter',
#   '2024-04-12',
#   'Андрей Фокин',
#   'Одноногий квадрокоптер подпрыгнул вверх на\xa0полтора метра'),
#  ('https://nplus1.ru/news/2024/03/28/emperor-wu',
#   '2024-03-28',
#   'Михаил Подрезов',
#   'Палеогенетики прочитали геном императора У-ди'),
#  ('https://nplus1.ru/news/2024/04/05/yellowstone-tourism-emissions',
#   '2024-04-05',
#   'Марина Попова',
#   'Туризм в\xa0Йеллоустоуне оказался причиной выброса миллиона тонн углекислого газа в\xa0год'),
#  ('https://nplus1.ru/news/2024/04/08/rodent-consumption',
#   '2024-04-08',
#   'Михаил Подрезов',
#   'Люди среднего каменного века Африки съели гунди'),
#  ('https://nplus1.ru/news/2024/04/01/fixed-lines-in-synchrotron',
#   '2024-04-01',
#   'Дмитрий Рудик',
#   'Физики обнаружили фиксированные линии в\xa0протонном суперсинхротроне'),
#  ('https://nplus1.ru/news/2024/04/02/mirror-image-cyclodextrins',
#   '2024-04-02',
#   'Михаил Бойм',
#   'Химики синтезировали неприродные энантиомеры циклодекстринов'),
#  ('https://nplus1.ru/news/2024/04/03/photons-to-tau',
#   '2024-04-03',
#   'Дмитрий Рудик',
#   'Два фотона превратились в\xa0два тау-лептона в\xa0протон-протонных столкновениях'),
#  ('https://nplus1.ru/news/2024/04/05/gan-microring-single-photon-source',
#   '2024-04-05',
#   'Оксана Борзенкова',
#   'Кольцо из\xa0нитрида галлия превратили в\xa0источник одиночных фотонов'),
#  ('https://nplus1.ru/news/2024/04/06/gw-bh-ns-or-no',
#   '2024-04-06',
#   'Александр Войтюк',
#   'Обсерватория LIGO увидела слияние нейтронной звезды и\xa0рекордно легкой черной дыры'),
#  ('https://nplus1.ru/news/2024/04/10/neutrino-ignored-quantum-gravity',
#   '2024-04-10',
#   'Дмитрий Рудик',
#   'На\xa0нейтрино не\xa0подействовала квантовая гравитация'),
#  ('https://nplus1.ru/news/2024/04/11/rotaxane-actuator',
#   '2024-04-11',
#   'Михаил Бойм',
#   'Ротаксан разгрузил молекулы в\xa0ответ на\xa0приложение силы'),
#  ('https://nplus1.ru/news/2024/04/12/magnetic-and-mergers',
#   '2024-04-12',
#   'Александр Войтюк',
#   'Замагниченность массивной звезды объяснили слиянием звезд в\xa0тройной системе'),
#  ('https://nplus1.ru/news/2024/04/15/bread-dark-photons',
#   '2024-04-15',
#   'Дмитрий Рудик',
#   'Физики не\xa0увидели темных фотонов от\xa0темной материи'),
#  ('https://nplus1.ru/news/2024/04/16/boat-sn',
#   '2024-04-16',
#   'Александр Войтюк',
#   'Самый яркий гамма-всплеск породил очень мало тяжелых элементов'),
#  ('https://nplus1.ru/news/2024/04/18/sympalamprey',
#   '2024-04-18',
#   'Олег Лищук',
#   'У\xa0миног нашли зачатки симпатической нервной системы'),
#  ('https://nplus1.ru/news/2024/04/18/ultrafast-kapitza-dirac',
#   '2024-04-18',
#   'Дмитрий Рудик',
#   'Физики увидели сверхбыстрый эффект Капицы\xa0— Дирака'),
#  ('https://nplus1.ru/news/2024/04/18/goldene-synthesis',
#   '2024-04-18',
#   'Михаил Бойм',
#   'Химики синтезировали голден'),
#  ('https://nplus1.ru/news/2024/04/18/jwst-w-1935',
#   '2024-04-18',
#   'Александр Войтюк',
#   '«Джеймс Уэбб» заметил нагрев стратосферы холодного коричневого карлика полярными сияниями')]

# %% [markdown]
# Так теперь выглядит первый элемент списка:

# %% [markdown]
# Импортируем `pandas` и создадим датафрейм из списка кортежей:

# %%
import pandas as pd

# %%
df = pd.DataFrame(news,columns = ['link', 'date', 'author', 'title'])

# %%
df.head(10)
# Out:
#                                                 link        date  \
# 0   https://nplus1.ru/news/2024/04/22/dogs-vs-tapirs  2024-04-22
# 1      https://nplus1.ru/news/2024/04/22/lead-mining  2024-04-22
# 2    https://nplus1.ru/news/2024/04/22/ici-pregnancy  2024-04-22
# 3  https://nplus1.ru/news/2024/04/22/beta-blocker...  2024-04-22
# 4  https://nplus1.ru/news/2024/04/20/deer-and-prions  2024-04-20
# 5   https://nplus1.ru/news/2024/04/20/covid-613-days  2024-04-20
# 6   https://nplus1.ru/news/2024/04/20/watch-yourself  2024-04-20
# 7   https://nplus1.ru/news/2024/04/20/rotavirus-wins  2024-04-20
# 8         https://nplus1.ru/news/2024/04/20/use-them  2024-04-20
# 9   https://nplus1.ru/news/2024/04/19/vasuki-indicus  2024-04-19
#
#             author                                              title
# 0   Сергей Коленов   Бродячих собак уличили в охоте на горных тапиров
# 1  Михаил Подрезов  Добытый в Польше свинец экспортировали в Древн...
# 2    Слава Гоменюк  Ингибиторы контрольных точек иммунитета не пов...
# 3    Слава Гоменюк  Бета-блокаторы не снизили риск смерти у пациен...
# 4   Сергей Коленов  Двух американских охотников назвали первыми во...
# 5    Слава Гоменюк  Ученые обнаружили новый штамм коронавируса у п...
# 6       Олег Лищук  Вероятность алкогольных блэкаутов связали со с...
# 7    Слава Гоменюк  Ротавирус оказался наиболее распространенным в...
# 8       Олег Лищук  Американские врачи пренебрегли новыми антибиот...
# 9   Сергей Коленов  Индийские палеонтологи описали потенциально кр...

# %% [markdown]
# Переименуем столбцы в базе.

# %%
df.head()
# Out:
#                                                 link        date  \
# 0      https://nplus1.ru/news/2024/04/22/lead-mining  2024-04-22
# 1    https://nplus1.ru/news/2024/04/22/ici-pregnancy  2024-04-22
# 2  https://nplus1.ru/news/2024/04/22/beta-blocker...  2024-04-22
# 3  https://nplus1.ru/news/2024/04/20/deer-and-prions  2024-04-20
# 4   https://nplus1.ru/news/2024/04/20/covid-613-days  2024-04-20
#
#             author                                              title
# 0  Михаил Подрезов  Добытый в Польше свинец экспортировали в Древн...
# 1    Слава Гоменюк  Ингибиторы контрольных точек иммунитета не пов...
# 2    Слава Гоменюк  Бета-блокаторы не снизили риск смерти у пациен...
# 3   Сергей Коленов  Двух американских охотников назвали первыми во...
# 4    Слава Гоменюк  Ученые обнаружили новый штамм коронавируса у п...

# %% [markdown]
# Всё! Сохраняем датафрейм в файл. Для разнообразия сохраним в Excel:

# %%
df.to_excel('nplus-news.xlsx', index=False)
